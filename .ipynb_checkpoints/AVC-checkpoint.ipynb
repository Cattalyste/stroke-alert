# %% [markdown]
# # stroke-alert

# %% [markdown]
# **Predictable variable: stroke**
# We are aiming to early predict and alert the stroke risk based on individual's demographical and health data.

# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline 
import seaborn as sns
from sklearn.model_selection import train_test_split,KFold
from sklearn.preprocessing import LabelEncoder,StandardScaler
from sklearn.feature_selection import RFE,RFECV
from sklearn.linear_model import LinearRegression, LogisticRegression
from sklearn.decomposition import PCA
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, confusion_matrix, mean_squared_error
from scipy.stats import pointbiserialr, chi2_contingency
import numpy as np

# %% [markdown]
# Original data:

# %%
df = pd.read_csv("AVC.csv")
df_original = df.copy()
df.head()
# Out:
#       id  gender   age  hypertension  heart_disease ever_married  \
# 0   9046    Male  67.0             0              1          Yes
# 1  51676  Female  61.0             0              0          Yes
# 2  31112    Male  80.0             0              1          Yes
# 3  60182  Female  49.0             0              0          Yes
# 4   1665  Female  79.0             1              0          Yes
#
#        work_type Residence_type  avg_glucose_level   bmi   smoking_status  \
# 0        Private          Urban             228.69  36.6  formerly smoked
# 1  Self-employed          Rural             202.21   NaN     never smoked
# 2        Private          Rural             105.92  32.5     never smoked
# 3        Private          Urban             171.23  34.4           smokes
# 4  Self-employed          Rural             174.12  24.0     never smoked
#
#    stroke
# 0       1
# 1       1
# 2       1
# 3       1
# 4       1

# %% [markdown]
# ## Data Cleaning

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5110 entries, 0 to 5109
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   id                 5110 non-null   int64
#  1   gender             5110 non-null   object
#  2   age                5110 non-null   float64
#  3   hypertension       5110 non-null   int64
#  4   heart_disease      5110 non-null   int64
#  5   ever_married       5110 non-null   object
#  6   work_type          5110 non-null   object
#  7   Residence_type     5110 non-null   object
#  8   avg_glucose_level  5110 non-null   float64
#  9   bmi                4909 non-null   float64
#  10  smoking_status     5110 non-null   object
#  11  stroke             5110 non-null   int64
# dtypes: float64(3), int64(4), object(5)
# memory usage: 479.2+ KB

# %% [markdown]
# BMI has 201 empty values

# %% [markdown]
# ### Initial data cleaning
# **Deleting 4 records stroke=0**

# %% [markdown]
# Converting categorical variables to numerical representations

# %%
categorical_vars = ['gender', 'hypertension', 'heart_disease', 'ever_married',
                    'work_type', 'Residence_type', 'smoking_status', 'stroke']

# Apply label encoding to the categorical variables
encoder = LabelEncoder()
df[categorical_vars] = df[categorical_vars].apply(encoder.fit_transform)

# %% [markdown]
# Deleting columns:
# - ID,
# - ever_married
#
# Records:
# - where BMI values are superior to 69

# %% [markdown]
# There is significant correlation between ever_married and age: **68%**

# %%
continuous_var = 'age'

binary_var = 'ever_married'

print(f'Point-biserial correlation coefficients for {continuous_var}:')
correlation_coefficient, p_value = pointbiserialr(df[continuous_var], df[binary_var])
print(f'{binary_var}: {correlation_coefficient:.4f} (p-value: {p_value:.4f})')
# Out:
# Point-biserial correlation coefficients for age:
# ever_married: 0.6791 (p-value: 0.0000)

# %% [markdown]
# Deleting columns ID, ever_married, records where BMI values are superior to 69:

# %%
#df = df.drop('id', axis=1)
df = df.drop('ever_married', axis=1)
df = df.drop(df[df['bmi'] >= 69].index) #IMC de 59 correspond à 170cm 200 Kg, les valeurs max sont à 97,6 (abérant)

# %% [markdown]
# Data records where BMI >= 69 (from original dataframe):

# %%
high_bmi_df = df_original[(df_original['bmi'] >= 69)]
high_bmi_df.sort_values(by='bmi', ascending=False)
# Out:
#          id  gender   age  hypertension  heart_disease ever_married work_type  \
# 2128  56420    Male  17.0             1              0           No   Private
# 4209  51856    Male  38.0             1              0          Yes   Private
# 928   41097  Female  23.0             1              0           No   Private
# 544     545    Male  42.0             0              0          Yes   Private
#
#      Residence_type  avg_glucose_level   bmi smoking_status  stroke
# 2128          Rural              61.67  97.6        Unknown       0
# 4209          Rural              56.90  92.0   never smoked       0
# 928           Urban              70.03  78.0         smokes       0
# 544           Rural             210.48  71.9   never smoked       0

# %%
plt.figure(figsize=(4, 5))
df_original.boxplot(column='bmi')
plt.title('Box Plot of BMI')
plt.ylabel('BMI')
plt.show()

# %% [markdown]
# Changing 'smoking_status' 0 ('Unknown') values to null:

# %%
# df['smoking_status'] = df['smoking_status'].replace(0, None)

# %% [markdown]
# ### Gender (more women than men)
# **Deleting 1 record stroke=0**

# %%
df_original.gender.value_counts().plot(kind='bar')
plt.show()

# %%
df.gender.value_counts().plot(kind='bar')
plt.show()

# %% [markdown]
# Removing 1 data sample with gender 'Other' (2)

# %%
df_gender_other = df_original[df_original['gender'] == 'Other']
df_gender_other
# Out:
#          id gender   age  hypertension  heart_disease ever_married work_type  \
# 3116  56156  Other  26.0             0              0           No   Private
#
#      Residence_type  avg_glucose_level   bmi   smoking_status  stroke
# 3116          Rural             143.33  22.4  formerly smoked       0

# %%
df = df.drop(df[df['gender'] == 2].index)

# %%
df_stroke = df[df['stroke'] == 1]
df_stroke.gender.value_counts().plot(kind='bar')
plt.show()

# %% [markdown]
# ### Residence type

# %%
df.Residence_type.value_counts().plot(kind='bar')
plt.show()

# %% [markdown]
# ### Work type (imbalanced)

# %%
df_original.work_type.value_counts().plot(kind='bar')
plt.show()

# %%
df.work_type.value_counts().plot(kind='bar')
plt.show()

# %%
df_stroke = df[df['stroke'] == 1]
df_stroke.work_type.value_counts().plot(kind='bar')
plt.show()

# %% [markdown]
# ### Smoking status
# **There are 1368 records where smoking_status is Unknown**

# %% [markdown]
# Original data:

# %%
df_original.smoking_status.value_counts().plot(kind='bar')
plt.show()

# %% [markdown]
# Initially cleaned dataframe data where nominal textual variables are converted to numerical:

# %%
df.smoking_status.value_counts().plot(kind='bar')
plt.show()

# %% [markdown]
# Calculating Null smoking_status values:

# %%
df_smoking_unknown = df[df['smoking_status']==0]
print(len(df_smoking_unknown))
# Out:
# 1543

# %% [markdown]
# **There are 1368 records where smoking_status is Unknown**

# %% [markdown]
# ### Hypertension (imbalanced)

# %%
df.hypertension.value_counts().plot(kind='bar')
plt.show()

# %%
df_stroke = df[df['stroke'] == 1]
df_stroke.hypertension.value_counts().plot(kind='bar')
plt.show()

# %% [markdown]
# ### Heart disease (imbalanced)

# %%
df.heart_disease.value_counts().plot(kind='bar')
plt.show()

# %%
df_stroke = df[df['stroke'] == 1]
df_stroke.heart_disease.value_counts().plot(kind='bar')
plt.show()

# %% [markdown]
# ### Stroke (imbalanced)

# %%
df.stroke.value_counts().plot(kind='bar')
plt.show()

# %% [markdown]
# There is a high imbalance in the data between the positive and negative stroke classes.

# %%
df.stroke.value_counts()
# Out:
# stroke
# 0    4856
# 1     249
# Name: count, dtype: int64

# %% [markdown]
# Almost **95%** of data records are in stroke class 0.

# %% [markdown]
# Since there are null bmi values, dealing with these missing values is an essential step to address before proceeding further to balancing classes.

# %% [markdown]
# ### Age
# **Deleting 1 record where age<=2.08, stroke=1,
# Deleting 174 records age<=2.08 and stroke=0**

# %% [markdown]
# Data distribution:

# %%
plt.figure(figsize=(5, 4))
plt.hist(df['age'], bins=41, color='lightblue', edgecolor='black')
plt.title('Distribution of Data in Age')
plt.xlabel('Unique Values')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# Calculating the histogram bin edges

# %%
# Calculate histogram values and bin edges
hist_values, bin_edges = np.histogram(df['age'], bins=41, range=(df['age'].min(), df['age'].max()))

# Print start and end points of each bin
for i, (start, end) in enumerate(zip(bin_edges[:-1], bin_edges[1:])):
    if i == 3: break
    print(f'Bin {i + 1}: Start: {start}, End: {end}')
# Out:
# Bin 1: Start: 0.08, End: 2.078048780487805
# Bin 2: Start: 2.078048780487805, End: 4.07609756097561
# Bin 3: Start: 4.07609756097561, End: 6.074146341463415

# %% [markdown]
# Age < 2.08 (first histogram bin) - values where stroke = 1:

# %%
test_df = df[(df['age'] <= 2.08) & (df['stroke'] == 1)]
test_df.sort_values(by='age', ascending=False)
# Out:
#         id  gender   age  hypertension  heart_disease  work_type  \
# 162  69768       0  1.32             0              0          4
#
#      Residence_type  avg_glucose_level  bmi  smoking_status  stroke
# 162               1              70.37  NaN               0       1

# %% [markdown]
# **One record with Positive stroke class will be removed**

# %% [markdown]
# Age < 2.08 (first histogram bin) - all values:

# %%
test_df = df[(df['age'] <= 2.08)]
print('In total Records to be deleted when age <= 2.08:', len(test_df))
# Out:
# In total Records to be deleted when age <= 2.08: 175

# %% [markdown]
# **Deleting the records where age < 2.08 (175 records)**

# %%
df = df.drop(df[df['age'] <= 30].index)

# %% [markdown]
# Stroke frequency based on the age distribution in the data:

# %%
plt.hist(df['age'], bins=50, color='skyblue', alpha=0.7, edgecolor='black', label='Age')

# Overlay the frequency line of stroke
plt.hist(df[df['stroke'] == 1]['age'], bins=50, color='red', alpha=0.5, edgecolor='black', label='Stroke')

# Add labels and title
plt.xlabel('Age')
plt.ylabel('Frequency')
plt.title('Histogram of Age with Stroke Frequency')
plt.legend()

# Show plot
plt.show()

# %%
age_min = df['age'].min()
age_max = df['age'].max()
print(age_min)
print(age_max)
bins = 20
bin_size = (age_max - age_min) / bins
print(bin_size)
bin_end = age_min
for bin_no in range(bins):
    bin_start = bin_end
    bin_end = bin_start + bin_size
    print('bin ', bin_no+1, ': ', round(bin_start, 2), ' - ', round(bin_end, 2))
# Out:
# 31.0
# 82.0
# 2.55
# bin  1 :  31.0  -  33.55
# bin  2 :  33.55  -  36.1
# bin  3 :  36.1  -  38.65
# bin  4 :  38.65  -  41.2
# bin  5 :  41.2  -  43.75
# bin  6 :  43.75  -  46.3
# bin  7 :  46.3  -  48.85
# bin  8 :  48.85  -  51.4
# bin  9 :  51.4  -  53.95
# bin  10 :  53.95  -  56.5
# bin  11 :  56.5  -  59.05
# bin  12 :  59.05  -  61.6
# bin  13 :  61.6  -  64.15
# bin  14 :  64.15  -  66.7
# bin  15 :  66.7  -  69.25
# bin  16 :  69.25  -  71.8
# bin  17 :  71.8  -  74.35
# bin  18 :  74.35  -  76.9
# bin  19 :  76.9  -  79.45
# bin  20 :  79.45  -  82.0

# %%
df_original_bmi_cleaned = df_original.drop(df_original[(df_original['bmi'] > 60)].index)

# %% [markdown]
# Searching for outliers of age based on stroke with a box plot:

# %%
plt.figure(figsize=(8, 6))
plt.boxplot([df[df['stroke'] == 1]['age'], df[df['stroke'] == 0]['age']], labels=['Stroke', 'No Stroke'])
plt.ylabel('Age')
plt.title('Box Plot of Age based on Stroke')
plt.grid(True)
plt.show()

# %% [markdown]
# Box plot confirms an outlier of 14 years old with a stroke.

# %%
df_age_outliers = df[(df['stroke'] == 1) & (df['age'] < 30)]
df_age_outliers
# Out:
# Empty DataFrame
# Columns: [id, gender, age, hypertension, heart_disease, work_type, Residence_type, avg_glucose_level, bmi, smoking_status, stroke]
# Index: []

# %% [markdown]
# ### Average glucose level

# %%
plt.figure(figsize=(5, 4))
plt.hist(df['avg_glucose_level'], bins=9, color='lightblue', edgecolor='black')
plt.title('Distribution of Data in Average Glucose Level')
plt.xlabel('Average glucose level')
plt.ylabel('Frequency')
plt.show()

# %%
plt.hist(df['avg_glucose_level'], bins=40, color='skyblue', alpha=0.7, edgecolor='black', label=' Average Glucose Level')

# Overlay the frequency line of stroke
plt.hist(df[df['stroke'] == 1]['avg_glucose_level'], bins=16, color='red', alpha=0.5, edgecolor='black', label='Stroke')

# Add labels and title
plt.xlabel('Average Glucose Level')
plt.ylabel('Frequency')
plt.title('Histogram of Average Glucose Level with Stroke Frequency')
plt.legend()

# Show plot
plt.show()

# %%
plt.figure(figsize=(8, 6))
plt.boxplot([df[df['stroke'] == 1]['avg_glucose_level'], df[df['stroke'] == 0]['avg_glucose_level']], labels=['Stroke', 'No Stroke'])
plt.ylabel('Average Glucose Level')
plt.title('Box Plot of Average Glucose Level based on Stroke')
plt.grid(True)
plt.show()

# %% [markdown]
# Average Glucose Level might falsely predict the Stroke as it sees all Negative Stroke class as outliers.

# %%
plt.figure(figsize=(6, 4))

# Plot data points with stroke = 0
plt.scatter(df[df['stroke'] == 0]['age'], df[df['stroke'] == 0]['avg_glucose_level'], color='blue', alpha=0.5, label='Stroke = 0')

# Plot data points with stroke = 1
plt.scatter(df[df['stroke'] == 1]['age'], df[df['stroke'] == 1]['avg_glucose_level'], color='red', alpha=0.5, label='Stroke = 1')

plt.title('Scatter Plot of BMI versus avg_glucose_level')
plt.xlabel('Age')
plt.ylabel('avg_glucose_level')
plt.grid(True)
plt.legend()  # Show legend to distinguish between the two stroke classes
plt.show()

# %% [markdown]
# ### BMI
# **There are 195 records where bmi is Unknown**
# **Deleting 4 records stroke=0**

# %% [markdown]
# Calculating null bmi values:

# %%
df_bmi_unknown = df[df['bmi'].isnull()]
print(len(df_bmi_unknown))
# Out:
# 167

# %% [markdown]
# **There are 195 empty BMI values**

# %%
df_original_bmi_cleaned = df.drop(df[(df['bmi'] > 60)].index)
plt.figure(figsize=(5, 4))
plt.hist(df_original_bmi_cleaned['bmi'], bins=18, color='lightblue', edgecolor='black')
plt.title('Distribution of Data in BMI')
plt.xlabel('Unique Values')
plt.ylabel('Frequency')
plt.show()

# %%
plt.figure(figsize=(8, 6))
plt.boxplot([df[df['stroke'] == 1]['bmi'], df[df['stroke'] == 0]['bmi']], labels=['Stroke', 'No Stroke'])
plt.ylabel('BMI')
plt.title('Box Plot of BMI based on Stroke')
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(5, 4))
plt.hist(df['bmi'], bins=18, color='lightblue', edgecolor='black')
plt.title('Distribution of Data in BMI')
plt.xlabel('Unique Values')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# BMI values are distrubuted correctly.

# %% [markdown]
# Data distribution on BMI with Stroke frequency:

# %%
plt.hist(df['bmi'], bins=16, color='skyblue', alpha=0.7, edgecolor='black', label='BMI')

# Overlay the frequency line of stroke
plt.hist(df[df['stroke'] == 1]['bmi'], bins=16, color='red', alpha=0.5, edgecolor='black', label='Stroke')

# Add labels and title
plt.xlabel('BMI')
plt.ylabel('Frequency')
plt.title('Histogram of BMI with Stroke Frequency')
plt.legend()

# Show plot
plt.show()

# %% [markdown]
# Data relationship between BMI and Age:

# %%
plt.figure(figsize=(6, 4))

# Plot data points with stroke = 0
plt.scatter(df[df['stroke'] == 0]['age'], df[df['stroke'] == 0]['bmi'], color='blue', alpha=0.5, label='Stroke = 0')

# Plot data points with stroke = 1
plt.scatter(df[df['stroke'] == 1]['age'], df[df['stroke'] == 1]['bmi'], color='red', alpha=0.5, label='Stroke = 1')

plt.title('Scatter Plot of BMI versus Age')
plt.xlabel('Age')
plt.ylabel('BMI')
plt.grid(True)
plt.legend()  # Show legend to distinguish between the two stroke classes
plt.show()

# %% [markdown]
# It seems like there may be a few anomalies in the data where age > 30 and very low BMI < 15

# %%
df_low_BMI = df[(df['bmi'] < 15) & (df['age'] > 30)]
df_low_BMI.sort_values(by='age')
# Out:
#          id  gender   age  hypertension  heart_disease  work_type  \
# 2187  59993       1  40.0             0              0          2
# 2661  59762       1  61.0             0              0          2
# 1930  28309       0  67.0             0              0          2
# 3307   3205       0  79.0             0              0          3
#
#       Residence_type  avg_glucose_level   bmi  smoking_status  stroke
# 2187               0              60.96  11.5               2       0
# 2661               1             227.98  14.2               0       0
# 1930               1              82.09  14.1               2       0
# 3307               1              79.03  11.3               0       0

# %% [markdown]
# These anomalies above might not represent the real world data, therefore, deleting these 4 records:

# %%
df = df.drop(df[(df['bmi'] < 15) & (df['age'] > 30)].index)

# %% [markdown]
# ### Dealing with missing values

# %% [markdown]
# Grouping the values of continuous variables (*age*, *average glucose level* and *bmi*) based on histogram with minimum logical number of bins for records grouping and finding missing BMI values.

# %% [markdown]
# Working with **df_grouped_cont_v** from here.

# %%
df_grouped_cont_v = df.copy()

# %% [markdown]
# ##### Age

# %%
plt.figure(figsize=(5, 4))
plt.hist(df_grouped_cont_v['age'], bins=13, color='lightblue', edgecolor='black')
plt.title('Distribution of Data in Age')
plt.xlabel('Unique Values')
plt.ylabel('Frequency')
plt.show()

# %%
hist_values, _ = np.histogram(df_grouped_cont_v['age'], bins=13, range=(df_grouped_cont_v['age'].min(), df_grouped_cont_v['age'].max()))
df_grouped_cont_v['age_histogram'] = np.digitize(df_grouped_cont_v['age'], bins=np.arange(df_grouped_cont_v['age'].min(), df_grouped_cont_v['age'].max(), (df_grouped_cont_v['age'].max()-df_grouped_cont_v['age'].min())/13))
df_grouped_cont_v
# Out:
#          id  gender   age  hypertension  heart_disease  work_type  \
# 0      9046       1  67.0             0              1          2
# 1     51676       0  61.0             0              0          3
# 2     31112       1  80.0             0              1          2
# 3     60182       0  49.0             0              0          2
# 4      1665       0  79.0             1              0          3
# ...     ...     ...   ...           ...            ...        ...
# 5105  18234       0  80.0             1              0          2
# 5106  44873       0  81.0             0              0          3
# 5107  19723       0  35.0             0              0          3
# 5108  37544       1  51.0             0              0          2
# 5109  44679       0  44.0             0              0          0
#
#       Residence_type  avg_glucose_level   bmi  smoking_status  stroke  \
# 0                  1             228.69  36.6               1       1
# 1                  0             202.21   NaN               2       1
# 2                  0             105.92  32.5               2       1
# 3                  1             171.23  34.4               3       1
# 4                  0             174.12  24.0               2       1
# ...              ...                ...   ...             ...     ...
# 5105               1              83.75   NaN               2       0
# 5106               1             125.20  40.0               2       0
# 5107               0              82.99  30.6               2       0
# 5108               0             166.29  25.6               1       0
# 5109               1              85.28  26.2               0       0
#
#       age_histogram
# 0                10
# 1                 8
# 2                13
# 3                 5
# 4                13
# ...             ...
# 5105             13
# 5106             13
# 5107              2
# 5108              6
# 5109              4
#
# [3534 rows x 12 columns]

# %% [markdown]
# ##### Average glucose level

# %%
plt.figure(figsize=(5, 4))
plt.hist(df_grouped_cont_v['avg_glucose_level'], bins=8, color='lightblue', edgecolor='black')
plt.title('Distribution of Data in Average Glucose Level')
plt.xlabel('Unique Values')
plt.ylabel('Frequency')
plt.show()

# %%
hist_values, _ = np.histogram(df_grouped_cont_v['avg_glucose_level'], bins=8, range=(df_grouped_cont_v['avg_glucose_level'].min(), df_grouped_cont_v['avg_glucose_level'].max()))
df_grouped_cont_v['avg_glucose_level_histogram'] = np.digitize(df_grouped_cont_v['avg_glucose_level'], bins=np.arange(df_grouped_cont_v['avg_glucose_level'].min(), df_grouped_cont_v['avg_glucose_level'].max(), (df_grouped_cont_v['avg_glucose_level'].max()-df_grouped_cont_v['avg_glucose_level'].min())/8))
df_grouped_cont_v
# Out:
#          id  gender   age  hypertension  heart_disease  work_type  \
# 0      9046       1  67.0             0              1          2
# 1     51676       0  61.0             0              0          3
# 2     31112       1  80.0             0              1          2
# 3     60182       0  49.0             0              0          2
# 4      1665       0  79.0             1              0          3
# ...     ...     ...   ...           ...            ...        ...
# 5105  18234       0  80.0             1              0          2
# 5106  44873       0  81.0             0              0          3
# 5107  19723       0  35.0             0              0          3
# 5108  37544       1  51.0             0              0          2
# 5109  44679       0  44.0             0              0          0
#
#       Residence_type  avg_glucose_level   bmi  smoking_status  stroke  \
# 0                  1             228.69  36.6               1       1
# 1                  0             202.21   NaN               2       1
# 2                  0             105.92  32.5               2       1
# 3                  1             171.23  34.4               3       1
# 4                  0             174.12  24.0               2       1
# ...              ...                ...   ...             ...     ...
# 5105               1              83.75   NaN               2       0
# 5106               1             125.20  40.0               2       0
# 5107               0              82.99  30.6               2       0
# 5108               0             166.29  25.6               1       0
# 5109               1              85.28  26.2               0       0
#
#       age_histogram  avg_glucose_level_histogram
# 0                10                            7
# 1                 8                            6
# 2                13                            2
# 3                 5                            5
# 4                13                            5
# ...             ...                          ...
# 5105             13                            2
# 5106             13                            3
# 5107              2                            2
# 5108              6                            5
# 5109              4                            2
#
# [3534 rows x 13 columns]

# %% [markdown]
# ##### BMI

# %%
plt.figure(figsize=(5, 4))
plt.hist(df_grouped_cont_v['bmi'], bins=9, color='lightblue', edgecolor='black')
plt.title('Distribution of Data in BMI')
plt.xlabel('Unique Values')
plt.ylabel('Frequency')
plt.show()

# %%
hist_values, _ = np.histogram(df_grouped_cont_v['bmi'], bins=9, range=(df_grouped_cont_v['bmi'].min(), df_grouped_cont_v['bmi'].max()))
df_grouped_cont_v['bmi_histogram'] = np.digitize(df_grouped_cont_v['bmi'], bins=np.arange(df_grouped_cont_v['bmi'].min(), df_grouped_cont_v['bmi'].max(), (df_grouped_cont_v['bmi'].max()-df_grouped_cont_v['bmi'].min())/9))
df_grouped_cont_v
# Out:
#          id  gender   age  hypertension  heart_disease  work_type  \
# 0      9046       1  67.0             0              1          2
# 1     51676       0  61.0             0              0          3
# 2     31112       1  80.0             0              1          2
# 3     60182       0  49.0             0              0          2
# 4      1665       0  79.0             1              0          3
# ...     ...     ...   ...           ...            ...        ...
# 5105  18234       0  80.0             1              0          2
# 5106  44873       0  81.0             0              0          3
# 5107  19723       0  35.0             0              0          3
# 5108  37544       1  51.0             0              0          2
# 5109  44679       0  44.0             0              0          0
#
#       Residence_type  avg_glucose_level   bmi  smoking_status  stroke  \
# 0                  1             228.69  36.6               1       1
# 1                  0             202.21   NaN               2       1
# 2                  0             105.92  32.5               2       1
# 3                  1             171.23  34.4               3       1
# 4                  0             174.12  24.0               2       1
# ...              ...                ...   ...             ...     ...
# 5105               1              83.75   NaN               2       0
# 5106               1             125.20  40.0               2       0
# 5107               0              82.99  30.6               2       0
# 5108               0             166.29  25.6               1       0
# 5109               1              85.28  26.2               0       0
#
#       age_histogram  avg_glucose_level_histogram  bmi_histogram
# 0                10                            7              4
# 1                 8                            6              9
# 2                13                            2              4
# 3                 5                            5              4
# 4                13                            5              2
# ...             ...                          ...            ...
# 5105             13                            2              9
# 5106             13                            3              5
# 5107              2                            2              3
# 5108              6                            5              2
# 5109              4                            2              2
#
# [3534 rows x 14 columns]

# %% [markdown]
# ##### Imputing missing BMI values

# %% [markdown]
# df_grouped_cont_v with 195 empty BMI values:

# %%
df_grouped_cont_v.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 3534 entries, 0 to 5109
# Data columns (total 14 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   id                           3534 non-null   int64
#  1   gender                       3534 non-null   int32
#  2   age                          3534 non-null   float64
#  3   hypertension                 3534 non-null   int64
#  4   heart_disease                3534 non-null   int64
#  5   work_type                    3534 non-null   int32
#  6   Residence_type               3534 non-null   int32
#  7   avg_glucose_level            3534 non-null   float64
#  8   bmi                          3367 non-null   float64
#  9   smoking_status               3534 non-null   int32
#  10  stroke                       3534 non-null   int64
#  11  age_histogram                3534 non-null   int64
#  12  avg_glucose_level_histogram  3534 non-null   int64
#  13  bmi_histogram                3534 non-null   int64
# dtypes: float64(3), int32(4), int64(7)
# memory usage: 358.9 KB

# %% [markdown]
# Grouping the df_grouped_cont_v data by all categorical parameters and continuous variables grouped to numerical histogram bin numbers:

# %%
grouped_data = df_grouped_cont_v.groupby(['gender', 'hypertension', 'heart_disease', 'work_type', 'Residence_type', 'smoking_status', 'stroke', 'age_histogram', 'avg_glucose_level_histogram'])

for group_name, group_data in grouped_data:
    if group_data['bmi'].isnull().any():
        print('New group: ', group_name)
        print(group_data)
        print()
# Out:
# New group:  (0, 0, 0, 0, 0, 1, 0, 2, 1)
#          id  gender   age  hypertension  heart_disease  work_type  \
# 
0             1              0          0
#
#       Residence_type  avg_glucose_level  bmi  smoking_status  stroke  \
# 3872               1              58.24  NaN               1       0
#
#       age_histogram  avg_glucose_level_histogram  bmi_histogram
# 3872              1                            1              9
#
# New group:  (1, 1, 0, 0, 1, 2, 0, 1, 2)
#         id  gender   age  hypertension  heart_disease  work_type  \
# 680  29873       1  31.0             1              0          0
#
#      Residence_type  avg_glucose_level  bmi  smoking_status  stroke  \
# 680               1              92.11  NaN               2       0
#
#      age_histogram  avg_glucose_level_histogram  bmi_histogram
# 680              1                            2              9
#
# New group:  (1, 1, 0, 2, 0, 0, 0, 1, 1)
#          id  gender   age  hypertension  heart_disease  work_type  \
# 4202  23194       1  32.0             1              0          2
#
#       Residence_type  avg_glucose_level  bmi  smoking_status  stroke  \
# 4202               0              74.43  NaN               0       0
#
#       age_histogram  avg_glucose_level_histogram  bmi_histogram
# 4202              1                            1              9
#
# New group:  (1, 1, 0, 2, 0, 0, 0, 4, 2)
#          id  gender   age  hypertension  heart_disease  work_type  \
# 3135  33704       1  44.0             1              0          2
#
#       Residence_type  avg_glucose_level  bmi  smoking_status  stroke  \
# 3135               0               84.1  NaN               0       0
#
#       age_histogram  avg_glucose_level_histogram  bmi_histogram
# 3135              4                            2              9
#
# New group:  (1, 1, 0, 2, 0, 0, 0, 11, 7)
#         id  gender   age  hypertension  heart_disease  work_type  \
# 2768  2885       1  72.0             1              0          2
#
#       Residence_type  avg_glucose_level  bmi  smoking_status  stroke  \
# 2768               0             231.71  NaN               0       0
#
#       age_histogram  avg_glucose_level_histogram  bmi_histogram
# 2768             11                            7              9
#
# New group:  (1, 1, 0, 2, 0, 1, 0, 6, 5)
#          id  gender   age  hypertension  heart_disease  work_type  \
# 1466  44950       1  51.0             1              0          2
#
#       Residence_type  avg_glucose_level  bmi  smoking_status  stroke  \
# 1466               0             163.56  NaN               1       0
#
#       age_histogram  avg_glucose_level_histogram  bmi_histogram
# 1466              6                            5              9
#
# New group:  (1, 1, 0, 2, 0, 2, 1, 13, 1)
#         id  gender   age  hypertension  heart_disease  work_type  \
# 167  43364       1  79.0             1              0          2
#
#      Residence_type  avg_glucose_level  bmi  smoking_status  stroke  \
# 167               0              75.02  NaN               2       1
#
#      age_histogram  avg_glucose_level_histogram  bmi_histogram
# 167             13                            1              9
#
# New group:  (1, 1, 0, 2, 0, 3, 0, 4, 1)
#          id  gender   age  hypertension  heart_disease  work_type  \
# 1293  68003       1  46.0             1              0          2
#
#       Residence_type  avg_glucose_level  bmi  smoking_status  stroke  \
# 1293               0              73.72  NaN               3       0
#
#       age_histogram  avg_glucose_level_histogram  bmi_histogram
# 1293              4                            1              9
#
# New group:  (1, 1, 0, 2, 0, 3, 0, 6, 6)
#         id  gender   age  hypertension  heart_disease  work_type  \
# 479  15649       1  54.0             1              0          2
#
#      Residence_type  avg_glucose_level  bmi  smoking_status  stroke  \
# 479               0             198.69  NaN               3       0
#
#      age_histogram  avg_glucose_level_histogram  bmi_histogram
# 479              6                            6              9
#
# New group:  (1, 1, 0, 2, 0, 3, 0, 10, 2)
#          id  gender   age  hypertension  heart_disease  work_type  \
# 1730  27135       1  69.0             1              0          2
#
#       Residence_type  avg_glucose_level  bmi  smoking_status  stroke  \
# 1730               0             107.11  NaN               3       0
#
#       age_histogram  avg_glucose_level_histogram  bmi_histogram
# 1730             10                            2              9
#
# New group:  (1, 1, 0, 2, 0, 3, 0, 12, 6)
#          id  gender   age  hypertension  heart_disease  work_type  \
# 2855  65196       1  75.0             1              0          2
#
#       Residence_type  avg_glucose_level  bmi  smoking_status  stroke  \
# 2855               0             198.79  NaN               3       0
#
#       age_histogram  avg_glucose_level_histogram  bmi_histogram
# 2855             12                            6              9
#
# New group:  (1, 1, 0, 2, 1, 1, 0, 5, 1)
#          id  gender   age  hypertension  heart_disease  work_type  \
# 2105  34248       1  50.0             1              0          2
#
#       Residence_type  avg_glucose_level  bmi  smoking_status  stroke  \
# 2105               1              81.96  NaN               1       0
#
#       age_histogram  avg_glucose_level_histogram  bmi_histogram
# 2105              5                            1              9
#
# New group:  (1, 1, 0, 2, 1, 1, 1, 12, 1)
#        id  gender   age  hypertension  heart_disease  work_type  \
# 51  15102       1  78.0             1              0          2
#
#     Residence_type  avg_glucose_level  bmi  smoking_status  stroke  \
# 51               1              75.32  NaN               1       1
#
#     age_histogram  avg_glucose_level_histogram  bmi_histogram
# 51             12                            1              9
#
# New group:  (1, 1, 0, 3, 0, 0, 0, 11, 2)
#          id  gender   age  hypertension  heart_disease  work_type  \
# 1183  13602       1  73.0             1              0          3
# 2872  42284       1  71.0             1              0          3
#
#       Residence_type  avg_glucose_level   bmi  smoking_status  stroke  \
# 1183               0             102.06   NaN               0       0
# 2872               0              97.57  26.9               0       0
#
#       age_histogram  avg_glucose_level_histogram  bmi_histogram
# 1183             11                            2              9
# 2872             11                            2              3
#
# New group:  (1, 1, 0, 3, 0, 0, 1, 11, 2)
#         id  gender   age  hypertension  heart_disease  work_type  \
# 247  34060       1  71.0             1              0          3
#
#      Residence_type  avg_glucose_level  bmi  smoking_status  stroke  \
# 247               0               87.8  NaN               0       1
#
#      age_histogram  avg_glucose_level_histogram  bmi_histogram
# 247             11                            2              9
#
# New group:  (1, 1, 0, 3, 0, 2, 0, 11, 2)
#          id  gender   age  hypertension  heart_disease  work_type  \
# 1546  29095       1  71.0             1              0          3
#
#       Residence_type  avg_glucose_level  bmi  smoking_status  stroke  \
# 1546               0               93.6  NaN               2       0
#
#       age_histogram  avg_glucose_level_histogram  bmi_histogram
# 1546             11                            2              9
#
# New group:  (1, 1, 0, 3, 1, 0, 0, 12, 2)
#         id  gender   age  hypertension  heart_disease  work_type  \
# 3162  2296       1  78.0             1              0          3
#
#       Residence_type  avg_glucose_level  bmi  smoking_status  stroke  \
# 3162               1              90.19  NaN               0       0
#
#       age_histogram  avg_glucose_level_histogram  bmi_histogram
# 3162             12                            2              9
#
# New group:  (1, 1, 0, 3, 1, 1, 1, 12, 2)
#        id  gender   age  hypertension  heart_disease  work_type  \
# 126  3352       1  78.0             1              0          3
#
#      Residence_type  avg_glucose_level  bmi  smoking_status  stroke  \
# 126               1              93.13  NaN               1       1
#
#      age_histogram  avg_glucose_level_histogram  bmi_histogram
# 126             12                            2              9
#
# New group:  (1, 1, 1, 2, 0, 2, 0, 8, 5)
#          id  gender   age  hypertension  heart_disease  work_type  \
# 2515  54807       1  62.0             1              1          2
#
#       Residence_type  avg_glucose_level  bmi  smoking_status  stroke  \
# 2515               0             176.25  NaN               2       0
#
#       age_histogram  avg_glucose_level_histogram  bmi_histogram
# 2515              8                            5              9

# %%
df_bmi_unknown = df_grouped_cont_v[df_grouped_cont_v['bmi'].isnull()]
# Extract id values of records with unknown BMI
unknown_bmi_ids = df_bmi_unknown['id'].tolist()
print('unknown_bmi_ids: ', sorted(unknown_bmi_ids), '\n')
df_bmi_unknown.sort_values(by='age', ascending=False)
# Out:
# unknown_bmi_ids:  [121, 132, 170, 298, 448, 739, 967, 1077, 1183, 1213, 1246, 1503, 1666, 1678, 1679, 1681, 1741, 1842, 1845, 1924, 1989, 2044, 2082, 2138, 2265, 2296, 2313, 2314, 2346, 2467, 2513, 2885, 3135, 3352, 3803, 4062, 4498, 4808, 5103, 5451, 5477, 5478, 5496, 5511, 5684, 5774, 6172, 6472, 6672, 6731, 6852, 7293, 7356, 7524, 7859, 8003, 8008, 8213, 8752, 8968, 9170, 10055, 10351, 11259, 11817, 11933, 11999, 12693, 13111, 13602, 14164, 15102, 15515, 15649, 16380, 16488, 16590, 16593, 16902, 17752, 18234, 18587, 18861, 18937, 19199, 19439, 20112, 21534, 21953, 22056, 22269, 22282, 22470, 22865, 23194, 24096, 25226, 25904, 26015, 26084, 27135, 27163, 27419, 28788, 28939, 29095, 29873, 31091, 31461, 31563, 32157, 32235, 33486, 33704, 34060, 34248, 34720, 35997, 36706, 37213, 37327, 37526, 37937, 39105, 39202, 40124, 40163, 40899, 41241, 42007, 42041, 42309, 42460, 43364, 43656, 44950, 45805, 46987, 48796, 49894, 50931, 51554, 51676, 52419, 53646, 53817, 54312, 54695, 54807, 56228, 57903, 60739, 61252, 61409, 61843, 62384, 63058, 65116, 65196, 66400, 66955, 68003, 68995, 69160, 70042, 70676, 72231]
#          id  gender   age  hypertension  heart_disease  work_type  \
# 4164  40163       0  82.0             1              0          2
# 1324    132       0  80.0             0              0          0
# 178   33486       0  80.0             0              0          0
# 5105  18234       0  80.0             1              0          2
# 150   11933       0  79.0             0              0          2
# ...     ...     ...   ...           ...            ...        ...
# 3872  61409       1  32.0             1              0          0
# 4984   1503       1  31.0             0              0          2
# 3214   1213       0  31.0             0              0          3
# 4069  12693       1  31.0             0              0          2
# 680   29873       1  31.0             1              0          0
#
#       Residence_type  avg_glucose_level  bmi  smoking_status  stroke  \
# 4164               1             222.52  NaN               1       0
# 1324               1              84.86  NaN               0       0
# 178                1             110.66  NaN               0       1
# 5105               1              83.75  NaN               2       0
# 150                0             169.67  NaN               0       1
# ...              ...                ...  ...             ...     ...
# 3872               1              58.24  NaN               1       0
# 4984               1             215.07  NaN               3       0
# 3214               1              87.23  NaN               1       0
# 4069               1             108.62  NaN               3       0
# 680                1              92.11  NaN               2       0
#
#       age_histogram  avg_glucose_level_histogram  bmi_histogram
# 4164             13                            7              9
# 1324             13                            2              9
# 178              13                            3              9
# 5105             13                            2              9
# 150              13                            5              9
# ...             ...                          ...            ...
# 3872              1                            1              9
# 4984              1                            6              9
# 3214              1                            2              9
# 4069              1                            2              9
# 680               1                            2              9
#
# [167 rows x 14 columns]

# %% [markdown]
# Calculating the average BMI value for each group and filling missing values in the group with the group average:

# %%
for group_name, group_data in grouped_data:
    nan_bmi_indices = group_data[group_data['bmi'].isnull()].index
    if nan_bmi_indices.any():
        group_average_bmi = group_data['bmi'].mean()
        group_average_bmi = round(group_average_bmi, 2)
        df_grouped_cont_v.loc[nan_bmi_indices, 'bmi'] = group_average_bmi

# %%
filtered_df = df_grouped_cont_v[df_grouped_cont_v['id'].isin(unknown_bmi_ids)]
filtered_df.sort_values(by='age', ascending=False)
# Out:
#          id  gender   age  hypertension  heart_disease  work_type  \
# 4164  40163       0  82.0             1              0          2
# 1324    132       0  80.0             0              0          0
# 178   33486       0  80.0             0              0          0
# 5105  18234       0  80.0             1              0          2
# 150   11933       0  79.0             0              0          2
# ...     ...     ...   ...           ...            ...        ...
# 3872  61409       1  32.0             1              0          0
# 4984   1503       1  31.0             0              0          2
# 3214   1213       0  31.0             0              0          3
# 4069  12693       1  31.0             0              0          2
# 680   29873       1  31.0             1              0          0
#
#       Residence_type  avg_glucose_level   bmi  smoking_status  stroke  \
# 4164               1             222.52   NaN               1       0
# 1324               1              84.86   NaN               0       0
# 178                1             110.66   NaN               0       1
# 5105               1              83.75  25.0               2       0
# 150                0             169.67   NaN               0       1
# ...              ...                ...   ...             ...     ...
# 3872               1              58.24   NaN               1       0
# 4984               1             215.07   NaN               3       0
# 3214               1              87.23   NaN               1       0
# 4069               1             108.62  33.8               3       0
# 680                1              92.11   NaN               2       0
#
#       age_histogram  avg_glucose_level_histogram  bmi_histogram
# 4164             13                            7              9
# 1324             13                            2              9
# 178              13                            3              9
# 5105             13                            2              9
# 150              13                            5              9
# ...             ...                          ...            ...
# 3872              1                            1              9
# 4984              1                            6              9
# 3214              1                            2              9
# 4069              1                            2              9
# 680               1                            2              9
#
# [167 rows x 14 columns]

# %%
df_bmi_unknown = df[df['bmi'].isnull()]
print('Records in the df where bmi is unknown before imputation:', len(df_bmi_unknown))
# Out:
# Records in the df where bmi is unknown before imputation: 167

# %%
# Iterate over the unknown BMI IDs and update corresponding records in df
for idx in unknown_bmi_ids:
    bmi_value = df_grouped_cont_v.loc[df_grouped_cont_v['id'] == idx, 'bmi'].iloc[0]
    df.loc[df['id'] == idx, 'bmi'] = bmi_value

# %%
df_bmi_unknown = df[df['bmi'].isnull()]
print('Records in the df where bmi is unknown after imputation:', len(df_bmi_unknown))
# Out:
# Records in the df where bmi is unknown after imputation: 124

# %% [markdown]
# ##### **After imputation 124 BMI values remain empty**

# %%
continuous_vars = ['age', 'avg_glucose_level', 'bmi']
continuous_df = df[continuous_vars].copy()
continuous_df.corr(method='pearson')

correlation_matrix = continuous_df.corr()
plt.figure(figsize=(5, 4))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f", linewidths=.5)
plt.title('Correlation Matrix between continuous variables')
plt.show()

# %%
df_without_null_bmi = df.dropna()
continuous_vars = ['bmi']

binary_vars = ['gender', 'hypertension', 'heart_disease', 'Residence_type', 'work_type', 'smoking_status']

for continuous_var in continuous_vars:
    print(f'Point-biserial correlation coefficients for {continuous_var}:')
    for binary_var in binary_vars:
        # Calculate the point-biserial correlation coefficient
        correlation_coefficient, p_value = pointbiserialr(df_without_null_bmi[continuous_var], df_without_null_bmi[binary_var])
        print(f'{binary_var}: {correlation_coefficient:.4f} (p-value: {p_value:.4f})')
    print('\n')
# Out:
# Point-biserial correlation coefficients for bmi:
# gender: 0.0194 (p-value: 0.2581)
# hypertension: 0.0906 (p-value: 0.0000)
# heart_disease: -0.0218 (p-value: 0.2026)
# Residence_type: -0.0025 (p-value: 0.8837)
# work_type: -0.0097 (p-value: 0.5725)
# smoking_status: 0.0045 (p-value: 0.7914)

# %% [markdown]
# Median: Use the median when the distribution of BMI values is skewed or when there are outliers present. The median is less sensitive to outliers compared to the mean and provides a robust measure of central tendency.

# %%
df_bmi_unknown = df_grouped_cont_v[df_grouped_cont_v['bmi'].isnull()]
# Extract id values of records with unknown BMI
unknown_bmi_ids = df_bmi_unknown['id'].tolist()
print('unknown_bmi_ids: ', sorted(unknown_bmi_ids), '\n')
df_bmi_unknown.sort_values(by='age', ascending=False)
# Out:
# unknown_bmi_ids:  [132, 170, 298, 967, 1077, 1213, 1503, 1666, 1681, 1845, 2044, 2082, 2296, 2313, 2314, 2346, 2513, 2885, 3352, 4062, 4498, 5477, 5478, 5496, 5774, 6172, 6731, 6852, 8008, 8213, 8752, 8968, 9170, 10055, 11259, 11817, 11933, 13111, 14164, 15102, 15515, 15649, 16590, 16593, 16902, 17752, 18587, 18937, 19199, 19439, 20112, 21534, 22056, 22269, 22282, 22470, 23194, 24096, 25226, 25904, 26015, 26084, 27135, 27163, 27419, 28788, 28939, 29095, 29873, 31091, 31461, 31563, 32157, 32235, 33486, 33704, 34060, 34248, 34720, 35997, 36706, 37213, 37327, 37526, 37937, 39105, 39202, 40124, 40163, 41241, 42041, 42460, 43364, 43656, 44950, 45805, 46987, 48796, 49894, 50931, 51676, 52419, 53646, 53817, 54695, 54807, 56228, 57903, 60739, 61252, 61409, 61843, 62384, 63058, 65116, 65196, 66400, 66955, 68003, 68995, 69160, 70042, 70676, 72231]
#          id  gender   age  hypertension  heart_disease  work_type  \
# 4164  40163       0  82.0             1              0          2
# 178   33486       0  80.0             0              0          0
# 1324    132       0  80.0             0              0          0
# 2541  61252       1  79.0             0              1          2
# 3913   6172       0  79.0             0              0          2
# ...     ...     ...   ...           ...            ...        ...
# 3872  61409       1  32.0             1              0          0
# 4202  23194       1  32.0             1              0          2
# 680   29873       1  31.0             1              0          0
# 3214   1213       0  31.0             0              0          3
# 4984   1503       1  31.0             0              0          2
#
#       Residence_type  avg_glucose_level  bmi  smoking_status  stroke  \
# 4164               1             222.52  NaN               1       0
# 178                1             110.66  NaN               0       1
# 1324               1              84.86  NaN               0       0
# 2541               0              82.27  NaN               2       0
# 3913               0             208.05  NaN               3       0
# ...              ...                ...  ...             ...     ...
# 3872               1              58.24  NaN               1       0
# 4202               0              74.43  NaN               0       0
# 680                1              92.11  NaN               2       0
# 3214               1              87.23  NaN               1       0
# 4984               1             215.07  NaN               3       0
#
#       age_histogram  avg_glucose_level_histogram  bmi_histogram
# 4164             13                            7              9
# 178              13                            3              9
# 1324             13                            2              9
# 2541             13                            1              9
# 3913             13                            6              9
# ...             ...                          ...            ...
# 3872              1                            1              9
# 4202              1                            1              9
# 680               1                            2              9
# 3214              1                            2              9
# 4984              1                            6              9
#
# [124 rows x 14 columns]

# %%
grouped_data = df_grouped_cont_v.groupby(['hypertension', 'heart_disease', 'work_type', 'smoking_status', 'age_histogram', 'avg_glucose_level_histogram'])

for group_name, group_data in grouped_data:
    nan_bmi_indices = group_data[group_data['bmi'].isnull()].index
    if nan_bmi_indices.any():
        group_average_bmi = group_data['bmi'].mean()
        group_average_bmi = round(group_average_bmi, 2)
        df_grouped_cont_v.loc[nan_bmi_indices, 'bmi'] = group_average_bmi
        print('New group: ', group_name)
        print(group_data)
        print()
# Out:
# New group:  (0, 0, 0, 0, 8, 5)
#         id  gender   age  hypertension  heart_disease  work_type  \
# 477  22470       1  61.0             0              0          0
#
#      Residence_type  avg_glucose_level  bmi  smoking_status  stroke  \
# 477               1             184.15  NaN               0       0
#
#      age_histogram  avg_glucose_level_histogram  bmi_histogram
# 477              8                            5              9
#
# New group:  (0, 0, 0, 0, 12, 1)
#          id  gender   age  hypertension  heart_disease  work_type  \
# 129   48796       0  75.0             0              0          0
# 1859  59250       0  78.0             0              0          0
# 2977  40870       0  75.0             0              0          0
# 4614  56425       0  78.0             0              0          0
# 4918  41842       1  75.0             0              0          0
#
#       Residence_type  avg_glucose_level   bmi  smoking_status  stroke  \
# 129                1              62.48   NaN               0       1
# 1859               1              58.88  35.8               0       0
# 2977               1              73.89  20.9               0       0
# 4614               0              61.38  24.3               0       0
# 4918               0              79.49  28.9               0       0
#
#       age_histogram  avg_glucose_level_histogram  bmi_histogram
# 129              12                            1              9
# 1859             12                            1              4
# 2977             12                            1              2
# 4614             12                            1              2
# 4918             12                            1              3
#
# New group:  (0, 0, 0, 0, 13, 2)
#        id  gender   age  hypertension  heart_disease  work_type  \
# 1324  132       0  80.0             0              0          0
#
#       Residence_type  avg_glucose_level  bmi  smoking_status  stroke  \
# 1324               1              84.86  NaN               0       0
#
#       age_histogram  avg_glucose_level_histogram  bmi_histogram
# 
 3)
#          id  gender   age  hypertension  heart_disease  work_type  \
# 53    47167       0  77.0             1              0          3
# 2192  26084       0  77.0             1              0          3
#
#       Residence_type  avg_glucose_level   bmi  smoking_status  stroke  \
# 53                 1             124.13  31.4               2       1
# 2192               1             109.51   NaN               2       0
#
#       age_histogram  avg_glucose_level_histogram  bmi_histogram
# 53               12                            3              3
# 2192             12                            3              9
#
# New group:  (1, 0, 3, 3, 6, 3)
#          id  gender   age  hypertension  heart_disease  work_type  \
# 2322  57903       0  52.0             1              0          3
#
#       Residence_type  avg_glucose_level  bmi  smoking_status  stroke  \
# 2322               0             111.38  NaN               3       0
#
#       age_histogram  avg_glucose_level_histogram  bmi_histogram
# 2322              6                            3              9
#
# New group:  (1, 0, 3, 3, 8, 1)
#          id  gender   age  hypertension  heart_disease  work_type  \
# 116   60744       1  61.0             1              0          3
# 3048  65116       0  62.0             1              0          3
#
#       Residence_type  avg_glucose_level   bmi  smoking_status  stroke  \
# 116                0              76.11  27.3               3       1
# 3048               1              75.78   NaN               3       0
#
#       age_histogram  avg_glucose_level_histogram  bmi_histogram
# 116               8                            1              3
# 3048              8                            1              9
#
# New group:  (1, 1, 2, 0, 10, 7)
#          id  gender   age  hypertension  heart_disease  work_type  \
# 2867  37526       0  68.0             1              1          2
#
#       Residence_type  avg_glucose_level  bmi  smoking_status  stroke  \
# 2867               0              233.3  NaN               0       0
#
#       age_histogram  avg_glucose_level_histogram  bmi_histogram
# 2867             10                            7              9
#
# New group:  (1, 1, 2, 1, 8, 7)
#          id  gender   age  hypertension  heart_disease  work_type  \
# 1503  39202       0  61.0             1              1          2
#
#       Residence_type  avg_glucose_level  bmi  smoking_status  stroke  \
# 1503               1             237.58  NaN               1       0
#
#       age_histogram  avg_glucose_level_histogram  bmi_histogram
# 1503              8                            7              9
#
# New group:  (1, 1, 2, 2, 8, 5)
#          id  gender   age  hypertension  heart_disease  work_type  \
# 2515  54807       1  62.0             1              1          2
#
#       Residence_type  avg_glucose_level  bmi  smoking_status  stroke  \
# 2515               0             176.25  NaN               2       0
#
#       age_histogram  avg_glucose_level_histogram  bmi_histogram
# 2515              8                            5              9
#
# New group:  (1, 1, 2, 2, 12, 6)
#          id  gender   age  hypertension  heart_disease  work_type  \
# 4684  49894       0  78.0             1              1          2
#
#       Residence_type  avg_glucose_level  bmi  smoking_status  stroke  \
# 4684               0             206.53  NaN               2       0
#
#       age_histogram  avg_glucose_level_histogram  bmi_histogram
# 4684             12                            6              9
#
# New group:  (1, 1, 3, 2, 13, 1)
#         id  gender   age  hypertension  heart_disease  work_type  \
# 171  60739       0  79.0             1              1          3
#
#      Residence_type  avg_glucose_level  bmi  smoking_status  stroke  \
# 171               0              60.94  NaN               2       1
#
#      age_histogram  avg_glucose_level_histogram  bmi_histogram
# 171             13                            1              9
#
# New group:  (1, 1, 3, 3, 12, 6)
#         id  gender   age  hypertension  heart_disease  work_type  \
# 218  25904       0  76.0             1              1          3
#
#      Residence_type  avg_glucose_level  bmi  smoking_status  stroke  \
# 218               1             199.86  NaN               3       1
#
#      age_histogram  avg_glucose_level_histogram  bmi_histogram
# 218             12                            6              9

# %%
# Iterate over the unknown BMI IDs and update corresponding records in df
for idx in unknown_bmi_ids:
    bmi_value = df_grouped_cont_v.loc[df_grouped_cont_v['id'] == idx, 'bmi'].iloc[0]
    df.loc[df['id'] == idx, 'bmi'] = bmi_value

# %%
df_bmi_unknown = df[df['bmi'].isnull()]
print('Records in the df where bmi is unknown after imputation:', len(df_bmi_unknown))
# Out:
# Records in the df where bmi is unknown after imputation: 73

# %%
df_bmi_unknown = df_grouped_cont_v[df_grouped_cont_v['bmi'].isnull()]
# Extract id values of records with unknown BMI
unknown_bmi_ids = df_bmi_unknown['id'].tolist()
print('unknown_bmi_ids: ', sorted(unknown_bmi_ids), '\n')
df_bmi_unknown.sort_values(by='age', ascending=False).head()
# Out:
# unknown_bmi_ids:  [132, 298, 967, 1077, 1503, 2044, 2082, 2313, 2513, 2885, 4062, 4498, 5477, 5496, 5774, 6172, 6852, 8213, 8752, 9170, 11817, 15515, 16902, 17752, 19439, 21534, 22056, 22269, 22282, 22470, 23194, 24096, 25226, 25904, 27163, 28939, 29095, 29873, 31091, 31461, 32235, 33486, 33704, 34720, 35997, 37213, 37327, 37526, 37937, 39202, 40124, 40163, 42041, 42460, 43656, 46987, 49894, 52419, 53646, 53817, 54695, 54807, 56228, 57903, 60739, 61409, 61843, 62384, 63058, 65196, 66955, 68003, 68995]
#          id  gender   age  hypertension  heart_disease  work_type  \
# 4164  40163       0  82.0             1              0          2
# 178   33486       0  80.0             0              0          0
# 1324    132       0  80.0             0              0          0
# 3913   6172       0  79.0             0              0          2
# 171   60739       0  79.0             1              1          3
#
#       Residence_type  avg_glucose_level  bmi  smoking_status  stroke  \
# 4164               1             222.52  NaN               1       0
# 178                1             110.66  NaN               0       1
# 1324               1              84.86  NaN               0       0
# 3913               0             208.05  NaN               3       0
# 171                0              60.94  NaN               2       1
#
#       age_histogram  avg_glucose_level_histogram  bmi_histogram
# 4164             13                            7              9
# 178              13                            3              9
# 1324             13                            2              9
# 3913             13                            6              9
# 171              13                            1              9

# %%
grouped_data = df_grouped_cont_v.groupby(['hypertension', 'work_type', 'smoking_status', 'age_histogram', 'avg_glucose_level_histogram'])

for group_name, group_data in grouped_data:
    nan_bmi_indices = group_data[group_data['bmi'].isnull()].index
    if nan_bmi_indices.any():
        group_average_bmi = group_data['bmi'].mean()
        group_average_bmi = round(group_average_bmi, 2)
        df_grouped_cont_v.loc[nan_bmi_indices, 'bmi'] = group_average_bmi
        print('New group: ', group_name)
        print(group_data)
        print()
# Out:
# New group:  (0, 0, 0, 7, 6)
#          id  gender   age  hypertension  heart_disease  work_type  \
# 19    25226       1  57.0             0              1          0
# 4377   8553       0  58.0             0              0          0
#
#       Residence_type  avg_glucose_level   bmi  smoking_status  stroke  \
# 19                 1             217.08   NaN               0       1
# 4377               0             195.74  32.7               0       0
#
#       age_histogram  avg_glucose_level_histogram  bmi_histogram
# 19                7                            6              9
# 4377              7                            6              4
#
# New group:  (0, 0, 0, 8, 5)
#         id  gender   age  hypertension  heart_disease  work_type  \
# 477  22470       1  61.0             0              0          0
#
#      Residence_type  avg_glucose_level  bmi  smoking_status  stroke  \
# 477               1             184.15  NaN               0       0
#
#      age_histogram  avg_glucose_level_histogram  bmi_histogram
# 477              8                            5              9
#
# New group:  (0, 0, 0, 12, 2)
#          id  gender   age  hypertension  heart_disease  work_type  \
# 420   20351       1  75.0             0              0          0
# 2321   1077       1  77.0             0              1          0
#
#       Residence_type  avg_glucose_level   bmi  smoking_status  stroke  \
# 420                1              94.29  35.2               0       0
# 2321               0             106.03   NaN               0       0
#
#       age_histogram  avg_glucose_level_histogram  bmi_histogram
# 420              12                            2              4
# 2321             12                            2              9
#
# New group:  (0, 0, 0, 13, 2)
#        id  gender   age  hypertension  heart_disease  work_type  \
# 1324  132       0  80.0             0              0          0
#
#       Residence_type  avg_glucose_level  bmi  smoking_status  stroke  \
# 1324               1              84.86  NaN               0       0
#
#       age_histogram  avg_glucose_level_histogram  bmi_histogram
# 1324             13                            2              9
#
# New group:  (0, 0, 0, 13, 3)
#         id  gender   age  hypertension  heart_disease  work_type  \
# 178  33486       0  80.0             0              0          0
#
#      Residence_type  avg_glucose_level  bmi  smoking_status  stroke  \
# 178               1             110.66  NaN               0       1
#
#      age_histogram  avg_glucose_level_histogram  bmi_histogram
# 178             13                            3              9
#
# New group:  (0, 0, 1, 7, 4)
#          id  gender   age  hypertension  heart_disease  work_type  \
# 3111  11817       1  58.0             0              0          0
#
#       Residence_type  avg_glucose_level  bmi  smoking_status  stroke  \
# 3111               1             160.87  NaN               1       0
#
#       age_histogram  avg_glucose_level_histogram  bmi_histogram
# 3111              7                            4              9
#
# New group:  (0, 0, 1, 8, 5)
#         id  gender   age  hypertension  heart_disease  work_type  \
# 1718  2513       1  59.0             0              1          0
#
#       Residence_type  avg_glucose_level  bmi  smoking_status  stroke  \
# 1718               1             188.69  NaN               1       0
#
#       age_histogram  avg_glucose_level_histogram  bmi_histogram
# 1718              8                            5              9
#
# New group:  (0, 0, 2, 9, 6)
#       id  gender   age  hypertension  heart_disease  work_type  \
# 54  8752       0  63.0             0              0          0
#
#     Residence_type  avg_glucose_level  bmi  smoking_status  stroke  \
# 54               1             197.54  NaN               2       1
#
#     age_histogram  avg_glucose_level_histogram  bmi_histogram
# 54              9                            6              9
#
# New group:  (0, 2, 0, 4, 2)
#          id  gender   age  hypertension  heart_disease  work_type  \
# 458   31164       0  43.0             0              0          2
# 557   62936       1  46.0             0              0          2
# 1670  34720       1  45.0             0              1          2
# 1796  11238       1  46.0             0              0          2
# 2402  37655       1  45.0             0              0          2
# 2495  34383       1  46.0             0              0          2
# 2594  63193       0  44.0             0              0          2
# 2851    205       0  43.0             0              0          2
# 3242  50651       0  45.0             0              0          2
# 3729  59880       1  45.0             0              0          2
# 3841  13328       0  45.0             0              0          2
# 4301  52172       0  44.0             0              0          2
# 4566  56600       0  43.0             0              0          2
# 4725  28348       0  46.0             0              0          2
# 4843  14036       1  44.0             0              0          2
# 5046  21467       1  44.0             0              0          2
# 5101  36901       0  45.0             0              0          2
#
#       Residence_type  avg_glucose_level   bmi  smoking_status  stroke  \
# 458                0              95.93  21.8               0       0
# 557                1             103.62  40.9               0       0
# 1670               0              93.77   NaN               0       0
# 1796               0              92.81  30.8               0       0
# 2402               0              83.91  40.2               0       0
# 2495               1              88.23  25.8               0       0
# 2594               0              88.75  25.6               0       0
# 2851               0              88.23  37.6               0       0
# 3242               0              91.47  24.2               0       0
# 3729               0              99.91  30.9               0       0
# 3841               0             106.95  33.4               0       0
# 4301               0              85.77  32.1               0       0
# 4566               0              84.04  30.6               0       0
# 4725               0             106.47  27.2               0       0
# 4843               0             101.46  29.4               0       0
# 5046               1              89.68  34.6               0       0
# 5101               1              97.95  24.5               0       0
#
#       age_histogram  avg_glucose_level_histogram  bmi_histogram
# 458               4                            2              2
# 557               4                            2              5
# 1670              4                            2              9
# 1796              4                            2              3
# 2402              4                            2              5
# 2495              4                            2              2
# 2594              4                            2              2
# 2851              4                            2              4
# 3242              4                            2              2
# 3729              4                            2              3
# 3841              4                            2              4
# 4301              4                            2              3
# 4566              4                            2              3
# 4725              4                            2              3
# 4843              4                            2              3
# 5046              4                            2              4
# 5101              4                            2              2
#
# New group:  (0, 2, 0, 7, 5)
#        id  gender   age  hypertension  heart_disease  work_type  \
#
 1)
#          id  gender   age  hypertension  heart_disease  work_type  \
# 69     7371       0  80.0             1              0          3
# 159   34567       0  81.0             1              0          3
# 171   60739       0  79.0             1              1          3
# 4355  38207       0  79.0             1              0          3
# 4443  41715       0  79.0             1              0          3
# 5100  68398       1  82.0             1              0          3
#
#       Residence_type  avg_glucose_level   bmi  smoking_status  stroke  \
# 69                 0              72.67  28.9               2       1
# 159                0              74.02  25.0               2       1
# 171                0              60.94   NaN               2       1
# 4355               0              76.64  19.5               2       0
# 4443               0              74.00  29.6               2       0
# 5100               0              71.97  28.3               2       0
#
#       age_histogram  avg_glucose_level_histogram  bmi_histogram
# 69               13                            1              3
# 159              13                            1              2
# 171              13                            1              9
# 4355             13                            1              1
# 4443             13                            1              3
# 5100             13                            1              3
#
# New group:  (1, 3, 3, 6, 3)
#          id  gender   age  hypertension  heart_disease  work_type  \
# 2322  57903       0  52.0             1              0          3
#
#       Residence_type  avg_glucose_level  bmi  smoking_status  stroke  \
# 2322               0             111.38  NaN               3       0
#
#       age_histogram  avg_glucose_level_histogram  bmi_histogram
# 2322              6                            3              9
#
# New group:  (1, 3, 3, 12, 6)
#         id  gender   age  hypertension  heart_disease  work_type  \
# 218  25904       0  76.0             1              1          3
#
#      Residence_type  avg_glucose_level  bmi  smoking_status  stroke  \
# 218               1             199.86  NaN               3       1
#
#      age_histogram  avg_glucose_level_histogram  bmi_histogram
# 218             12                            6              9

# %%
# Iterate over the unknown BMI IDs and update corresponding records in df
for idx in unknown_bmi_ids:
    bmi_value = df_grouped_cont_v.loc[df_grouped_cont_v['id'] == idx, 'bmi'].iloc[0]
    df.loc[df['id'] == idx, 'bmi'] = bmi_value

# %%
df_bmi_unknown = df[df['bmi'].isnull()]
print('Records in the df where bmi is unknown after imputation:', len(df_bmi_unknown))
# Out:
# Records in the df where bmi is unknown after imputation: 48

# %%
df_bmi_unknown = df_grouped_cont_v[df_grouped_cont_v['bmi'].isnull()]
# Extract id values of records with unknown BMI
unknown_bmi_ids = df_bmi_unknown['id'].tolist()
print('unknown_bmi_ids: ', sorted(unknown_bmi_ids), '\n')
df_bmi_unknown.sort_values(by='age', ascending=False).head()
# Out:
# unknown_bmi_ids:  [132, 298, 1503, 2082, 2513, 4062, 5496, 5774, 6852, 8213, 8752, 9170, 11817, 15515, 22056, 22269, 22282, 22470, 23194, 24096, 25904, 27163, 29095, 29873, 32235, 33486, 33704, 35997, 37327, 37526, 37937, 39202, 40163, 42041, 42460, 43656, 52419, 53646, 53817, 54695, 54807, 57903, 61409, 61843, 63058, 65196, 68003, 68995]
#          id  gender   age  hypertension  heart_disease  work_type  \
# 4164  40163       0  82.0             1              0          2
# 1324    132       0  80.0             0              0          0
# 178   33486       0  80.0             0              0          0
# 2494  35997       1  78.0             0              1          3
# 13     8213       1  78.0             0              1          2
#
#       Residence_type  avg_glucose_level  bmi  smoking_status  stroke  \
# 4164               1             222.52  NaN               1       0
# 1324               1              84.86  NaN               0       0
# 178                1             110.66  NaN               0       1
# 2494               1             243.73  NaN               3       0
# 13                 1             219.84  NaN               0       1
#
#       age_histogram  avg_glucose_level_histogram  bmi_histogram
# 4164             13                            7              9
# 1324             13                            2              9
# 178              13                            3              9
# 2494             12                            7              9
# 13               12                            7              9

# %%
grouped_data = df_grouped_cont_v.groupby(['work_type', 'smoking_status', 'age_histogram', 'avg_glucose_level_histogram'])

for group_name, group_data in grouped_data:
    nan_bmi_indices = group_data[group_data['bmi'].isnull()].index
    if nan_bmi_indices.any():
        group_average_bmi = group_data['bmi'].mean()
        group_average_bmi = round(group_average_bmi, 2)
        df_grouped_cont_v.loc[nan_bmi_indices, 'bmi'] = group_average_bmi
        print('New group: ', group_name)
        print(group_data)
        print()
# Out:
# New group:  (0, 0, 8, 5)
#         id  gender   age  hypertension  heart_disease  work_type  \
# 477  22470       1  61.0             0              0          0
#
#      Residence_type  avg_glucose_level  bmi  smoking_status  stroke  \
# 477               1             184.15  NaN               0       0
#
#      age_histogram  avg_glucose_level_histogram  bmi_histogram
# 477              8                            5              9
#
# New group:  (0, 0, 13, 2)
#        id  gender   age  hypertension  heart_disease  work_type  \
# 1324  132       0  80.0             0              0          0
#
#       Residence_type  avg_glucose_level  bmi  smoking_status  stroke  \
# 1324               1              84.86  NaN               0       0
#
#       age_histogram  avg_glucose_level_histogram  bmi_histogram
# 1324             13                            2              9
#
# New group:  (0, 0, 13, 3)
#         id  gender   age  hypertension  heart_disease  work_type  \
#
2       0
#
#       age_histogram  avg_glucose_level_histogram  bmi_histogram
# 199              11                            1              3
# 227              11                            1              9
# 232              11                            1              4
# 1106             11                            1              9
# 1953             11                            1              3
# 2935             11                            1              2
# 3007             11                            1              9
# 3115             11                            1              3
# 3663             11                            1              3
# 4769             11                            1              2
#
# New group:  (3, 2, 11, 2)
#          id  gender   age  hypertension  heart_disease  work_type  \
# 933   19681       0  74.0             0              0          3
# 1546  29095       1  71.0             1              0          3
# 2440  12336       0  73.0             0              0          3
# 3569  35648       0  74.0             0              0          3
#
#       Residence_type  avg_glucose_level   bmi  smoking_status  stroke  \
# 933                1              99.21  22.1               2       0
# 1546               0              93.60   NaN               2       0
# 2440               1              87.56  24.1               2       0
# 3569               0              95.94  27.0               2       0
#
#       age_histogram  avg_glucose_level_histogram  bmi_histogram
# 933              11                            2              2
# 1546             11                            2              9
# 2440             11                            2              2
# 3569             11                            2              3
#
# New group:  (3, 3, 5, 6)
#          id  gender   age  hypertension  heart_disease  work_type  \
# 1468  42460       1  48.0             0              0          3
# 1756  15515       0  48.0             0              0          3
#
#       Residence_type  avg_glucose_level  bmi  smoking_status  stroke  \
# 1468               0             216.88  NaN               3       0
# 1756               0             209.90  NaN               3       0
#
#       age_histogram  avg_glucose_level_histogram  bmi_histogram
# 1468              5                            6              9
# 1756              5                            6              9
#
# New group:  (3, 3, 6, 3)
#          id  gender   age  hypertension  heart_disease  work_type  \
# 629   46218       0  51.0             0              0          3
# 1870  60050       0  53.0             0              0          3
# 2322  57903       0  52.0             1              0          3
#
#       Residence_type  avg_glucose_level   bmi  smoking_status  stroke  \
# 629                1             111.15  34.1               3       0
# 1870               1             113.74  31.6               3       0
# 2322               0             111.38   NaN               3       0
#
#       age_histogram  avg_glucose_level_histogram  bmi_histogram
# 629               6                            3              4
# 1870              6                            3              3
# 2322              6                            3              9
#
# New group:  (3, 3, 12, 6)
#         id  gender   age  hypertension  heart_disease  work_type  \
# 218  25904       0  76.0             1              1          3
#
#      Residence_type  avg_glucose_level  bmi  smoking_status  stroke  \
# 218               1             199.86  NaN               3       1
#
#      age_histogram  avg_glucose_level_histogram  bmi_histogram
# 218             12                            6              9
#
# New group:  (3, 3, 12, 7)
#          id  gender   age  hypertension  heart_disease  work_type  \
# 2494  35997       1  78.0             0              1          3
#
#       Residence_type  avg_glucose_level  bmi  smoking_status  stroke  \
# 2494               1             243.73  NaN               3       0
#
#       age_histogram  avg_glucose_level_histogram  bmi_histogram
# 2494             12                            7              9

# %%
# Iterate over the unknown BMI IDs and update corresponding records in df
for idx in unknown_bmi_ids:
    bmi_value = df_grouped_cont_v.loc[df_grouped_cont_v['id'] == idx, 'bmi'].iloc[0]
    df.loc[df['id'] == idx, 'bmi'] = bmi_value

# %%
df_bmi_unknown = df[df['bmi'].isnull()]
print('Records in the df where bmi is unknown after imputation:', len(df_bmi_unknown))
# Out:
# Records in the df where bmi is unknown after imputation: 24

# %%
df_bmi_unknown = df_grouped_cont_v[df_grouped_cont_v['bmi'].isnull()]
# Extract id values of records with unknown BMI
unknown_bmi_ids = df_bmi_unknown['id'].tolist()
print('unknown_bmi_ids: ', sorted(unknown_bmi_ids), '\n')
df_bmi_unknown.sort_values(by='age', ascending=False).head()
# Out:
# unknown_bmi_ids:  [132, 1503, 2082, 2513, 4062, 5496, 5774, 9170, 11817, 15515, 22269, 22470, 25904, 33486, 35997, 37327, 42041, 42460, 43656, 52419, 54695, 61843, 63058, 65196]
#          id  gender   age  hypertension  heart_disease  work_type  \
# 1324    132       0  80.0             0              0          0
# 178   33486       0  80.0             0              0          0
# 2494  35997       1  78.0             0              1          3
# 867   63058       0  77.0             0              1          2
# 218   25904       0  76.0             1              1          3
#
#       Residence_type  avg_glucose_level  bmi  smoking_status  stroke  \
# 1324               1              84.86  NaN               0       0
# 178                1             110.66  NaN               0       1
# 2494               1             243.73  NaN               3       0
# 867                0             183.10  NaN               2       0
# 218                1             199.86  NaN               3       1
#
#       age_histogram  avg_glucose_level_histogram  bmi_histogram
# 1324             13                            2              9
# 178              13                            3              9
# 2494             12                            7              9
# 867              12                            5              9
# 218              12                            6              9

# %%
grouped_data = df_grouped_cont_v.groupby(['work_type', 'age_histogram', 'avg_glucose_level_histogram'])

for group_name, group_data in grouped_data:
    nan_bmi_indices = group_data[group_data['bmi'].isnull()].index
    if nan_bmi_indices.any():
        group_average_bmi = group_data['bmi'].mean()
        group_average_bmi = round(group_average_bmi, 2)
        df_grouped_cont_v.loc[nan_bmi_indices, 'bmi'] = group_average_bmi
        print('New group: ', group_name)
        print(group_data)
        print()
# Out:
# New group:  (0, 7, 4)
#          id  gender   age  hypertension  heart_disease  work_type  \
# 166   63453       0  56.0             0              0          0
# 3111  11817       1  58.0             0              0          0
# 4092  49901       1  55.0             0              0          0
#
#       Residence_type  avg_glucose_level   bmi  smoking_status  stroke  \
# 166                0             162.23  27.3               0       1
# 3111               1             160.87   NaN               1       0
# 4092               1             154.03  31.6               3       0
#
#       age_histogram  avg_glucose_level_histogram  bmi_histogram
# 166               7                            4              3
# 3111              7                            4              9
# 4092              7                            4              3
#
# New group:  (0, 8, 5)
#          id  gender   age  hypertension  heart_disease  work_type  \
# 477   22470       1  61.0             0              0          0
# 1718   2513       1  59.0             0              1          0
# 1898  25405       1  62.0             0              0          0
#
#       Residence_type  avg_glucose_level   bmi  smoking_status  stroke  \
# 477                1             184.15   NaN               0       0
# 1718               1             188.69   NaN               1       0
# 1898               1             187.52  57.7               2       0
#
#       age_histogram  avg_glucose_level_histogram  bmi_histogram
# 477               8                            5              9
# 1718              8                            5              9
# 1898              8                            5              8
#
# New group:  (0, 8, 8)
#          id  gender   age  hypertension  heart_disease  work_type  \
# 2462  27626       0  60.0             0              0          0
# 4283  43656       1  59.0             1              0          0
#
#       Residence_type  avg_glucose_level   bmi  smoking_status  stroke  \
# 2462               0             266.59  25.5               2       0
# 4283               0             253.93   NaN               1       0
#
#       age_histogram  avg_glucose_level_histogram  bmi_histogram
# 2462              8                            8              2
# 4283              8                            8              9
#
# New group:  (0, 10, 3)
#          id  gender   age  hypertension  heart_disease  work_type  \
# 1918  33144       0  68.0             0              0          0
# 2343  22269       0  69.0             1              0          0
# 4635  37640       0  67.0             0              0          0
#
#       Residence_type  avg_glucose_level   bmi  smoking_status  stroke  \
# 1918               1             121.66  29.1               3       0
# 2343               1             112.20   NaN               2       0
# 4635               0             125.33  26.4               0       0
#
#       age_histogram  avg_glucose_level_histogram  bmi_histogram
# 1918             10                            3              3
# 2343             10                            3              9
# 4635             10                            3              2
#
# New group:  (0, 13, 2)
#          id  gender   age  hypertension  heart_disease  work_type  \
# 140   20439       1  82.0             0              1          0
# 168   44993       0  79.0             1              0          0
# 1044  66752       0  79.0             0              0          0
# 1160  52550       0  79.0             0              0          0
# 1324    132       0  80.0             0              0          0
# 2715  60003       1  81.0             0              0          0
# 3399  40167       0  79.0             1              1          0
# 4375  33560       0  81.0             0              1          0
# 4719  23968       0  79.0             0              0          0
# 4988  30525       0  79.0             0              0          0
#
#       Residence_type  avg_glucose_level   bmi  smoking_status  stroke  \
# 140                0             103.68  25.0               2       1
# 168                1              98.02  22.3               1       1
# 1044               1              93.89  30.4               2       0
# 1160               1              83.56  28.7               3       0
# 1324               1              84.86   NaN               0       0
# 2715               0              89.02  26.9               2       0
# 3399               0              83.61  21.4               3       0
# 4375               1              90.11  28.6               2       0
# 4719               0              90.16  34.4               2       0
# 4988               1              95.42  21.5               1       0
#
#       age_histogram  avg_glucose_level_histogram  bmi_histogram
# 140              13                            2              2
# 168              13                            2              2
# 1044             13                            2              3
# 1160             13                            2              3
# 1324             13                            2              9
# 2715             13                            2              3
# 3399             13                            2              2
# 4375             13                            2              3
# 4719             13                            2              4
# 4988             13                            2              2
#
# New group:  (0, 13, 3)
#          id  gender   age  hypertension  heart_disease  work_type  \
# 178   33486       0  80.0             0              0          0
# 3659  42594       1  80.0             1              0          0
#
#       Residence_type  avg_glucose_level   bmi  smoking_status  stroke  \
# 178                1             110.66   NaN               0       1
# 3659               1             114.09  30.1               2       0
#
#       age_histogram  avg_glucose_level_histogram  bmi_histogram
# 178              13                            3              9
# 3659             13                            3              3
#
# New group:  (2, 1, 6)
#          id  gender   age  hypertension  heart_disease  work_type  \
# 1888  61247       0  32.0             0              0          2
# 4984   1503       1  31.0             0              0          2
#
#       Residence_type  avg_glucose_level   bmi  smoking_status  stroke  \
# 1888               0             199.18  27.9               2       0
# 4984               1             215.07   NaN               3       0
#
#       age_histogram  avg_glucose_level_histogram  bmi_histogram
# 1888              1                            6              3
# 4984              1                            6              9
#
# New group:  (2, 2, 3)
#          id  gender   age  hypertension  heart_disease  work_type  \
# 

#          id  gender   age  hypertension  heart_disease  work_type  \
# 138   29281       1  76.0             1              0          3
# 218   25904       0  76.0             1              1          3
# 233   23368       0  77.0             1              0          3
# 360   54312       0  76.0             1              0          3
# 929   36618       1  75.0             0              1          3
# 970   10538       1  75.0             1              1          3
# 1343  54526       1  76.0             1              0          3
# 1971  48775       0  78.0             1              0          3
# 2102  50671       1  78.0             1              1          3
# 2336   9026       0  78.0             1              0          3
# 2934   9079       0  76.0             0              1          3
# 3146  13358       0  75.0             0              0          3
# 3148   6032       1  78.0             0              0          3
# 3234  56635       1  76.0             1              0          3
# 3387  65277       0  78.0             1              0          3
# 3625  40210       1  78.0             0              1          3
# 4129  11312       0  78.0             0              0          3
# 4376  37866       0  76.0             0              0          3
# 4514  46670       0  75.0             1              0          3
#
#       Residence_type  avg_glucose_level   bmi  smoking_status  stroke  \
# 138                0             194.37  27.0               1       1
# 218                1             199.86   NaN               3       1
# 233                1             199.84  28.0               1       1
# 360                1             209.58  24.5               2       0
# 929                1             207.64  30.5               1       0
# 970                1             195.03  28.7               1       0
# 1343               0             197.58  34.8               1       0
# 1971               0             201.07  21.8               0       0
# 2102               0             199.88  29.6               1       0
# 2336               1             191.33  24.5               2       0
# 2934               1             202.21  39.3               1       0
# 3146               0             207.62  31.8               2       0
# 3148               1             201.58  30.6               0       0
# 3234               0             207.96  34.5               1       0
# 3387               0             198.12  29.1               2       0
# 3625               0             206.62  28.0               1       0
# 4129               0             208.99  31.4               1       0
# 4376               1             193.61  37.6               2       0
# 4514               0             197.06  26.1               2       0
#
#       age_histogram  avg_glucose_level_histogram  bmi_histogram
# 138              12                            6              3
# 218              12                            6              9
# 233              12                            6              3
# 360              12                            6              9
# 929              12                            6              3
# 970              12                            6              3
# 1343             12                            6              4
# 1971             12                            6              2
# 2102             12                            6              3
# 2336             12                            6              2
# 2934             12                            6              5
# 3146             12                            6              3
# 3148             12                            6              3
# 3234             12                            6              4
# 3387             12                            6              3
# 3625             12                            6              3
# 4129             12                            6              3
# 4376             12                            6              4
# 4514             12                            6              2
#
# New group:  (3, 12, 7)
#          id  gender   age  hypertension  heart_disease  work_type  \
# 234   25974       1  78.0             0              0          3
# 256   41413       0  75.0             0              1          3
# 1414  47622       1  78.0             0              1          3
# 1531  49709       0  77.0             1              0          3
# 2494  35997       1  78.0             0              1          3
# 3017  33009       1  76.0             0              0          3
# 3600  26076       0  75.0             1              0          3
# 4708  18263       0  78.0             0              0          3
#
#       Residence_type  avg_glucose_level   bmi  smoking_status  stroke  \
# 234                1             218.46  26.8               0       1
# 256                0             243.53  27.0               2       0
# 1414               1             228.70  34.0               0       0
# 1531               0             238.53  30.6               2       0
# 2494               1             243.73   NaN               3       0
# 3017               0             221.80  44.7               1       0
# 3600               0             219.82  29.5               1       0
# 4708               1             234.06  33.7               2       0
#
#       age_histogram  avg_glucose_level_histogram  bmi_histogram
# 234              12                            7              3
# 256              12                            7              3
# 1414             12                            7              4
# 1531             12                            7              3
# 2494             12                            7              9
# 3017             12                            7              6
# 3600             12                            7              3
# 4708             12                            7              4

# %%
# Iterate over the unknown BMI IDs and update corresponding records in df
for idx in unknown_bmi_ids:
    bmi_value = df_grouped_cont_v.loc[df_grouped_cont_v['id'] == idx, 'bmi'].iloc[0]
    df.loc[df['id'] == idx, 'bmi'] = bmi_value

# %%
df_bmi_unknown = df[df['bmi'].isnull()]
print('Records in the df where bmi is unknown after imputation:', len(df_bmi_unknown))
# Out:
# Records in the df where bmi is unknown after imputation: 0

# %%
df_bmi_unknown = df[df['bmi'].isnull()]
df_bmi_unknown
# Out:
# Empty DataFrame
# Columns: [id, gender, age, hypertension, heart_disease, work_type, Residence_type, avg_glucose_level, bmi, smoking_status, stroke]
# Index: []

# %%
df = df.drop(df[(df['id'] == 51852)].index)

# %% [markdown]
# ### BMI vs Age
# **Deleting 9 records stroke=0**

# %% [markdown]
# Analyzing BMI versus Age outliers:

# %%
plt.figure(figsize=(8, 6))
sns.boxplot(x='age_histogram', y='bmi', data=df_grouped_cont_v)
plt.title('Box Plot of BMI versus Age (df_grouped_cont_v)')
plt.xlabel('Age histogram bins')
plt.ylabel('BMI')
plt.show()

# %% [markdown]
# Age histogram that represent age groups:

# %%
plt.figure(figsize=(5, 4))
plt.hist(df_grouped_cont_v['age'], bins=13, edgecolor='black')
plt.title('Distribution of Data in Age')
plt.xlabel('Unique Values')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# Records that have BMI > 60:

# %%
df_high_BMI = df[(df['bmi'] >= 60)]
print(len(df_high_BMI), ' records:')
df_high_BMI.sort_values(by='age', ascending=False)
# Out:
# 7  records:
#          id  gender   age  hypertension  heart_disease  work_type  \
# 466    1307       0  61.0             1              0          2
# 270   72911       0  57.0             1              0          2
# 1559  37759       0  53.0             0              0          2
# 358   66333       1  52.0             0              0          3
# 2840  65895       0  52.0             0              0          2
# 3825  72784       0  52.0             0              0          2
# 4838   5131       0  51.0             0              0          2
#
#       Residence_type  avg_glucose_level   bmi  smoking_status  stroke
# 466                0             170.05  60.2               3       0
# 270                0             129.54  60.9               3       0
# 1559               0              72.63  66.8               0       0
# 358                1              78.40  64.8               2       0
# 2840               1              98.27  61.2               0       0
# 3825               0             118.46  61.6               3       0
# 4838               1             107.72  60.9               0       0

# %% [markdown]
# All 9 records are have stroke Negative class. Deleting these outliers:

# %%
df = df.drop(df[df['bmi'] >= 60].index)

# %% [markdown]
# ### Resampling

# %% [markdown]
# Imbalanced variables (except for stroke): gender (take men), work_type (exclude 4), hypertension (take 1), heart_disease (take 1)

# %%
df_age_balance = df_original.drop(df_original[(df_original['age'] < 60)].index)

# %%
plt.hist(df['age'], bins=16, color='skyblue', alpha=0.7, edgecolor='black', label='Age')

# Overlay the frequency line of stroke
plt.hist(df[df['stroke'] == 1]['age'], bins=16, color='red', alpha=0.5, edgecolor='black', label='Stroke')

# Add labels and title
plt.xlabel('Age')
plt.ylabel('Frequency')
plt.title('Histogram of Age with Stroke Frequency')
plt.legend()

# Show plot
plt.show()

# %%
from sklearn.utils import resample

# Separate majority and minority classes
majority_class = df[df['stroke'] == 0]
minority_class = df[df['stroke'] == 1]

# Upsample minority class
minority_upsampled = resample(minority_class,
                               replace=True, # Sample with replacement
                               n_samples=len(majority_class), # Match size of majority class
                               random_state=4) # Reproducible results

# Combine majority class with upsampled minority class
df_balanced_random_oversampling = pd.concat([majority_class, minority_upsampled])

# %%
from imblearn.over_sampling import SMOTE

# Separate features and target variable
X = df.drop('stroke', axis=1)
y = df['stroke']

# Apply SMOTE
smote = SMOTE(random_state=42)
X_smote, y_smote = smote.fit_resample(X, y)

# Concatenate features and target variable
df_balanced_SMOTE = pd.concat([pd.DataFrame(X_smote, columns=X.columns), pd.DataFrame(y_smote, columns=['stroke'])], axis=1)

# %%
plt.hist(df_balanced_random_oversampling['age'], bins=41, color='skyblue', alpha=0.7, edgecolor='black', label='Age')

# Overlay the frequency line of stroke
plt.hist(df_balanced_random_oversampling[df_balanced_random_oversampling['stroke'] == 1]['age'], bins=41, color='red', alpha=0.5, edgecolor='black', label='Stroke')

# Add labels and title
plt.xlabel('Age')
plt.ylabel('Frequency')
plt.title('Histogram of Age with Stroke Frequency')
plt.legend()

# Show plot
plt.show()

# %%
plt.hist(df_balanced_SMOTE['age'], bins=41, color='skyblue', alpha=0.7, edgecolor='black', label='Age')

# Overlay the frequency line of stroke
plt.hist(df_balanced_SMOTE[df_balanced_SMOTE['stroke'] == 1]['age'], bins=41, color='red', alpha=0.5, edgecolor='black', label='Stroke')

# Add labels and title
plt.xlabel('Age')
plt.ylabel('Frequency')
plt.title('Histogram of Age with Stroke Frequency')
plt.legend()

# Show plot
plt.show()

# %%
# Separate majority (stroke = 0) and minority (stroke = 1) classes
majority_class = df[df['stroke'] == 0]
minority_class = df[(df['stroke'] == 1)]

# Repeat the minority class (stroke = 1) samples to triple their size
minority_oversampled = pd.concat([minority_class] * 3, ignore_index=True)

# Combine majority class with oversampled minority class
df_balanced_triple_stroke = pd.concat([majority_class, minority_oversampled])

# Shuffle the dataframe to randomize the order of samples
df_balanced_triple_stroke = df_balanced_triple_stroke.sample(frac=1, random_state=65000).reset_index(drop=True)


plt.hist(df_balanced_triple_stroke['age'], bins=51, color='skyblue', alpha=0.7, edgecolor='black', label='Age')

# Overlay the frequency line of stroke
plt.hist(df_balanced_triple_stroke[df_balanced_triple_stroke['stroke'] == 1]['age'], bins=51, color='red', alpha=0.5, edgecolor='black', label='Stroke')

# Add labels and title
plt.xlabel('Age')
plt.ylabel('Frequency')
plt.title('Histogram of Age with Stroke Frequency')
plt.legend()

# Show plot
plt.show()

# %% [markdown]
# ## Correlation & Association

# %% [markdown]
# #### Continuous variables

# %%
df[['age','avg_glucose_level','bmi']].describe()
# Out:
#                age  avg_glucose_level          bmi
# count  3527.000000        3527.000000  3527.000000
# mean     55.489935         111.407959    30.877349
# std      14.601430          50.288073     6.811849
# min      31.000000          55.220000    15.000000
# 25%      43.000000          77.945000    26.200000
# 50%      55.000000          93.360000    29.800000
# 75%      67.000000         120.355000    34.400000
# max      82.000000         271.740000    59.700000

# %% [markdown]
# #### Categorical variables (binary & nominal)

# %%
continuous_data_columns = ['age', 'avg_glucose_level', 'bmi']
df_categorical_data = df.drop(columns=continuous_data_columns)
df_categorical_data.head()
# Out:
#       id  gender  hypertension  heart_disease  work_type  Residence_type  \
# 0   9046       1             0              1          2               1
# 1  51676       0             0              0          3               0
# 2  31112       1             0              1          2               0
# 3  60182       0             0              0          2               1
# 4   1665       0             1              0          3               0
#
#    smoking_status  stroke
# 0               1       1
# 1               2       1
# 2               2       1
# 3               3       1
# 4               2       1

# %% [markdown]
# #### Heatmap

# %%
cor = df.corr()
fig,ax = plt.subplots(figsize=(12,12))
sns.heatmap(cor,annot=True,ax=ax,cmap='coolwarm');

# %%
df.head()
# Out:
#       id  gender   age  hypertension  heart_disease  work_type  \
# 0   9046       1  67.0             0              1          2
# 1  51676       0  61.0             0              0          3
# 2  31112       1  80.0             0              1          2
# 3  60182       0  49.0             0              0          2
# 4   1665       0  79.0             1              0          3
#
#    Residence_type  avg_glucose_level   bmi  smoking_status  stroke
# 0               1             228.69  36.6               1       1
# 1               0             202.21  39.2               2       1
# 2               0             105.92  32.5               2       1
# 3               1             171.23  34.4               3       1
# 4               0             174.12  24.0               2       1

# %%
# sns.pairplot(df,kind="kde")

# %% [markdown]
# #### Correlation between categorical binary variable *stroke* and continuous variables *age*, *glucose_level*, and *bmi*

# %%
continuous_vars = ['age', 'avg_glucose_level', 'bmi']

binary_vars = ['stroke']

df_without_null_bmi = df.dropna()

for continuous_var in continuous_vars:
    print(f'Point-biserial correlation coefficients for {continuous_var}:')
    for binary_var in binary_vars:
        # Calculate the point-biserial correlation coefficient
        correlation_coefficient, p_value = pointbiserialr(df_without_null_bmi[continuous_var], df_without_null_bmi[binary_var])
        print(f'{binary_var}: {correlation_coefficient:.4f} (p-value: {p_value:.4f})')
    print('\n')
# Out:
# Point-biserial correlation coefficients for age:
# stroke: 0.2392 (p-value: 0.0000)
#
#
# Point-biserial correlation coefficients for avg_glucose_level:
# stroke: 0.1184 (p-value: 0.0000)
#
#
# Point-biserial correlation coefficients for bmi:
# stroke: -0.0242 (p-value: 0.1512)

# %% [markdown]
# There is a significant correlation between :
# - **stroke and age (23%)**, and
# - **stroke and average glucose level (13%)**

# %% [markdown]
# After bmi data imputation,

# %% [markdown]
# #### Variables associated with age

# %% [markdown]
# **Age** strongly correlates with :
# - **average glucose level (24%)** and
# - **bmi (28%)**

# %%
continuous_df = df[continuous_vars].copy()
continuous_df.corr(method='pearson')

correlation_matrix = continuous_df.corr()
plt.figure(figsize=(5, 4))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f", linewidths=.5)
plt.title('Correlation Matrix between continuous variables')
plt.show()

# %% [markdown]
# Age correlation with categorical variables:

# %%
continuous_vars = ['age']

binary_vars = ['gender', 'hypertension', 'heart_disease', 'Residence_type', 'work_type', 'smoking_status']

for continuous_var in continuous_vars:
    print(f'Point-biserial correlation coefficients for {continuous_var}:')
    for binary_var in binary_vars:
        # Calculate the point-biserial correlation coefficient
        correlation_coefficient, p_value = pointbiserialr(df[continuous_var], df[binary_var])
        print(f'{binary_var}: {correlation_coefficient:.4f} (p-value: {p_value:.4f})')
    print('\n')
# Out:
# Point-biserial correlation coefficients for age:
# gender: 0.0355 (p-value: 0.0348)
# hypertension: 0.2098 (p-value: 0.0000)
# heart_disease: 0.2602 (p-value: 0.0000)
# Residence_type: 0.0246 (p-value: 0.1446)
# work_type: 0.1472 (p-value: 0.0000)
# smoking_status: -0.0821 (p-value: 0.0000)

# %% [markdown]
# **Age** has a significant association with :
# - **hypertension (27%)**,
# - **heart_disease (26%)**,
# - **work_type (29%)**, and
# - **smoking_status (21%)**

# %% [markdown]
# #### Correlation between categorical binary variable *stroke* and categorical binary & nominal variables *gender*, *hypertension*, *heart_disease*, *Residence_type*, *work_type*, and *smoking_status*

# %%
categorical_variables = ['gender', 'hypertension', 'heart_disease', 'work_type', 'Residence_type', 'smoking_status']

for var in categorical_variables:
    contingency_table = pd.crosstab(df['stroke'], df[var])
    chi2, p, dof, expected = chi2_contingency(contingency_table)
    print(f"Chi-squared test for {var}:")
    print(f"Chi2 Statistic: {chi2}")
    print(f"P-value: {p}")
    print("")
# Out:
# Chi-squared test for gender:
# Chi2 Statistic: 0.9770658754416415
# P-value: 0.32292426938531327
#
# Chi-squared test for hypertension:
# Chi2 Statistic: 36.72884293343951
# P-value: 1.3575595484650957e-09
#
# Chi-squared test for heart_disease:
# Chi2 Statistic: 45.32111801868254
# P-value: 1.6723611030696122e-11
#
# Chi-squared test for work_type:
# Chi2 Statistic: 4.21557930408599
# P-value: 0.12150624090554057
#
# Chi-squared test for Residence_type:
# Chi2 Statistic: 1.0965017893802869
# P-value: 0.2950350990623876
#
# Chi-squared test for smoking_status:
# Chi2 Statistic: 5.583156903477222
# P-value: 0.1337486538512851

# %% [markdown]
# **Stroke** has a significant association with:
# - **Hypertension**,
# - **heart_disease**,
# - **work_type** and
# - **smoking_status**

# %% [markdown]
# ## Supervised classification (with 1 feature)

# %% [markdown]
# - **Splitting the DataFrame into training and testing sets**,
# - **Standardizing the features** using StandardScaler() to ensure they have a mean of 0 and a standard deviation of 1.
# - Testing data set = 20%

# %% [markdown]
# #### Comment

# %%
aha
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[104], line 1
# ----> 1 aha
#
# NameError: name 'aha' is not defined

# %%
df_smoke=df.drop(['gender','heart_disease','hypertension','Residence_type'],axis=1)
X_train_smoke, X_test_smoke, y_train_smoke, y_test_smoke = train_test_split(df_smoke.drop('smoking_status', axis=1),df_smoke['smoking_status'],test_size = .2)
scaler_smoke = StandardScaler()
X_train_smoke = scaler_smoke.fit_transform(X_train_smoke)
X_test_smoke = scaler_smoke.transform(X_test_smoke)

# %%
rfc_smoke = RandomForestClassifier()
rfe_smoke = RFE(estimator=rfc_smoke, step=1, n_features_to_select = 1)
rfe_smoke.fit(X_train_smoke, y_train_smoke)
mask_smoke = rfe_smoke.get_support()
plt.matshow(mask_smoke.reshape(1,-1), cmap = 'gray_r')
plt.xlabel('Axe des features');

# %%
ranking_smoke = rfe_smoke.ranking_
plt.matshow(ranking_smoke.reshape(1,-1), cmap = 'gray_r')
plt.xlabel('Axe des features');
plt.show();

# %%
df.head()

# %%
from sklearn import model_selection
from sklearn import neighbors
from sklearn import svm
clf = svm.SVC(gamma=0.01,  kernel='poly')

df_smoke=df.drop(['gender','heart_disease','hypertension','Residence_type'],axis=1)
df_smoke = df_smoke[df_smoke.smoking_status != 0]
X_train_smoke, X_test_smoke, y_train_smoke, y_test_smoke = train_test_split(df_smoke.drop('smoking_status', axis=1),df_smoke['smoking_status'],test_size = .2)

scaler_smoke = StandardScaler()
X_train_smoke = scaler_smoke.fit_transform(X_train_smoke)
X_test_smoke = scaler_smoke.transform(X_test_smoke)

score_minko = []
score_man = []
score_cheb = []

for k in range(1, 41):
    knn = neighbors.KNeighborsClassifier(n_neighbors=k)
    knn.fit(X_train_smoke, y_train_smoke)
    score_minko.append(knn.score(X_test_smoke, y_test_smoke))

for k in range(1, 41):
    knn = neighbors.KNeighborsClassifier(n_neighbors=k, metric='manhattan')
    knn.fit(X_train_smoke, y_train_smoke)
    score_man.append(knn.score(X_test_smoke, y_test_smoke))
    
for k in range(1, 41):
    knn = neighbors.KNeighborsClassifier(n_neighbors=k, metric='chebyshev')
    knn.fit(X_train_smoke, y_train_smoke)
    score_cheb.append(knn.score(X_test_smoke, y_test_smoke))
    


parametres = {'C':[0.1,1,10], 'kernel':['rbf','linear', 'poly'], 'gamma':[0.001, 0.1, 0.5]}

grid_clf = model_selection.GridSearchCV(estimator=clf, param_grid=parametres,verbose=3)

#grille = grid_clf.fit(X_train_smoke,y_train_smoke)

print(grid_clf.best_params_)

clf = svm.SVC(C=0.1 ,gamma=0.001,  kernel='rbf')
clf.fit(X_train_smoke, y_train_smoke)

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

plt.plot(range(1, 41), score_minko, color='blue', linestyle='dashed', lw=2, label='Minkowski')
plt.plot(range(1, 41), score_man, color='orange', linestyle='dashed', lw=2, label='Manhattan')
plt.plot(range(1, 41), score_cheb, color='red', linestyle='dashed', lw=2, label='Chebyshev')
plt.title('Score - valeur de K')  
plt.xlabel('Valeur de K')  
plt.ylabel('Accuracy') 
plt.legend();

# %%
rfc=RandomForestClassifier(random_state=42)
param_grid = { 
    'n_estimators': [200, 500],
    'max_features': ['sqrt', 'log2'],
    'max_depth' : [4,5,6,7,8],
    'criterion' :['gini', 'entropy']
}
CV_rfc = GridSearchCV(estimator=rfc, param_grid=param_grid, cv= 5)
CV_rfc.fit(X_train, y_train)

# %%
CV_rfc.best_params_

# %%
LR=LogisticRegression(random_state=42)
param_grid = {
    'C': [0.001, 0.01, 0.1, 1, 10, 100],
    'penalty': ['l2'],
    'max_iter' : [100,300,600,1000]
}
CV_rfc = GridSearchCV(estimator=LR, param_grid=param_grid, cv= 5)
CV_rfc.fit(X_train, y_train)

# %%
CV_rfc.best_params_

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.ensemble import VotingClassifier, StackingClassifier
from sklearn.model_selection import train_test_split, KFold, cross_validate
from sklearn.metrics import f1_score
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier

df_smoke=df.drop(['gender','heart_disease','hypertension','Residence_type'],axis=1)
df_smoke = df_smoke[df_smoke.smoking_status != 0]
X_train, X_test, y_train, y_test = train_test_split(df_smoke.drop('smoking_status', axis=1),df_smoke['smoking_status'],test_size = .2)

scaler_smoke = StandardScaler()
X_train = scaler_smoke.fit_transform(X_train)
X_test = scaler_smoke.transform(X_test)
from sklearn.model_selection import GridSearchCV

param_grid = {'max_features': ['sqrt', 'log2'],
              'ccp_alpha': [0.1, .01, .001],
              'max_depth' : [5, 6, 7, 8, 9],
              'criterion' :['gini', 'entropy']
             }
tree_clas = DecisionTreeClassifier(random_state=1024)
grid_search = GridSearchCV(estimator=tree_clas, param_grid=param_grid, cv=5, verbose=True)
grid_search.fit(X_train, y_train)

# %%
grid_search.best_params_

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.ensemble import VotingClassifier, StackingClassifier
from sklearn.model_selection import train_test_split, KFold, cross_validate
from sklearn.metrics import f1_score
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from imblearn.under_sampling import RandomUnderSampler
from imblearn.over_sampling import RandomOverSampler
from imblearn.over_sampling import SMOTE, ADASYN



df_smoke=df.drop(['gender','heart_disease','hypertension','Residence_type'],axis=1)
df_smoke = df_smoke[df_smoke.smoking_status != 0]
X_train, X_test, y_train, y_test = train_test_split(df_smoke.drop('smoking_status', axis=1),df_smoke['smoking_status'],test_size = .2)

scaler_smoke = StandardScaler()
X_train = scaler_smoke.fit_transform(X_train)
X_test = scaler_smoke.transform(X_test)

"""
X_train, y_train = ADASYN().fit_resample(X_train, y_train)
X_train, y_train = SMOTE().fit_resample(X_train, y_train)
print(y_train.value_counts())
over = RandomOverSampler(sampling_strategy={2:1500,1:800,3:800})
under = RandomUnderSampler(sampling_strategy={2:800,1:800,3:800})
X_train, y_train = over.fit_resample(X_train, y_train)
X_train, y_train = under.fit_resample(X_train, y_train)
print(y_train.value_counts())
"""

clf1 = KNeighborsClassifier(n_neighbors=40, metric='chebyshev')
clf2 = RandomForestClassifier(criterion='entropy',max_depth=6,max_features='sqrt',n_estimators=500)
clf3 = LogisticRegression(max_iter=100,C=0.001,penalty='l2')
#clf4 = svm.SVC(C=0.1 ,gamma=0.001,  kernel='rbf')
clf5 = DecisionTreeClassifier(ccp_alpha= 0.1,criterion='gini', max_depth= 5, max_features= 'sqrt')

vclf = VotingClassifier(estimators=[('knn', clf1), ('rf', clf2), ('lr', clf3), ('DT', clf5)], voting='soft')

cv3 = KFold(n_splits=3, random_state=111, shuffle=True)

for clf, label in zip([clf1, clf2, clf3, clf5, vclf], ['KNN', 'Random Forest', 'Logistic Regression', 'SVC','Decision Tree', 'Voting Classifier']):
    scores = cross_validate(clf, X_train, y_train, cv=cv3, scoring=['accuracy','f1_weighted'])
    print("[%s]: \n Accuracy: %0.2f (+/- %0.2f)" % (label, scores['test_accuracy'].mean(), scores['test_accuracy'].std()),
          "F1 score: %0.2f (+/- %0.2f)" % (scores['test_f1_weighted'].mean(), scores['test_f1_weighted'].std()))

print("--------------------------------------------")

sclf = StackingClassifier(estimators=[('knn', clf1), ('rf', clf2), ('lr', clf3),('DT',clf5)], final_estimator=clf5)

scores = cross_validate(sclf, X_train, y_train, cv=cv3, scoring=['accuracy', 'f1_weighted'])

print("[StackingClassifier]: \n Accuracy: %0.2f (+/- %0.2f)\n" % (scores['test_accuracy'].mean(), scores['test_accuracy'].std()),
      "F1 score: %0.2f (+/- %0.2f)" % (scores['test_f1_weighted'].mean(), scores['test_f1_weighted'].std()))

# %%
clf1.fit(X_train, y_train)
clf2.fit(X_train, y_train)
clf3.fit(X_train, y_train)
clf5.fit(X_train, y_train)
vclf.fit(X_train, y_train)
sclf.fit(X_train, y_train)

print("Acc :", clf1.score(X_test, y_test))
print("Acc :", clf2.score(X_test, y_test))
print("Acc :", clf3.score(X_test, y_test))
print("Acc :", clf5.score(X_test, y_test))
print("Acc :", vclf.score(X_test, y_test))
print("Acc :", sclf.score(X_test, y_test))

# %%
y_pred = vclf.predict(X_test)
pd.crosstab(y_test, y_pred, rownames=['Classe réelle'], colnames=['Classe prédite'])

# %%
from sklearn.metrics import classification_report
print(classification_report(y_test, y_pred))

# %%
clf1 : acc=0.46  rec = 0.51  F1 = 0.40
clf2 : acc=0.60  rec = 0.55  F1 = 0.40
vclf : acc=0.60  rec = 0.55  F1 = 0.40

# %%
print(y_train.value_counts())

# %% [markdown]
# #### Random Forrest

# %% [markdown]
# ##### Algorithm

# %%
df.head()

# %%
X_train, X_test, y_train, y_test = train_test_split(df.drop('stroke', axis=1),df['stroke'],test_size = .2)
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# %%
rfc1 = RandomForestClassifier()
rfe = RFE(estimator=rfc1, step=1, n_features_to_select = 1)
rfe.fit(X_train, y_train)
mask = rfe.get_support()
plt.matshow(mask.reshape(1,-1), cmap = 'gray_r')
plt.xlabel('Axe des features');

# %%
mask

# %%
ranking = rfe.ranking_
plt.matshow(ranking.reshape(1,-1), cmap = 'gray_r')
plt.xlabel('Axe des features');
plt.show();

# %%
df.head()

# %% [markdown]
# ##### Evaluation

# %%
lm = LinearRegression()
rfc = RandomForestClassifier()

crossval = KFold(n_splits = 5, random_state = 2, shuffle = True)
rfecv = RFECV(estimator=rfc, cv = crossval, step=1)
rfecv.fit(X_train, y_train)

mask = rfecv.get_support()
plt.matshow(mask.reshape(1,-1), cmap = 'gray_r')
plt.xlabel('Axe des features');
plt.show();

# %%
plt.plot(rfecv.cv_results_['mean_test_score']);
print("Nombre de features retenus :", rfecv.n_features_)

# %%
rfecv.cv_results_['mean_test_score']

# %% [markdown]
# #### Binary Logistic Regression

# %% [markdown]
# ##### Algorithm

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 3527 entries, 0 to 5109
# Data columns (total 11 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   id                 3527 non-null   int64
#  1   gender             3527 non-null   int32
#  2   age                3527 non-null   float64
#  3   hypertension       3527 non-null   int64
#  4   heart_disease      3527 non-null   int64
#  5   work_type          3527 non-null   int32
#  6   Residence_type     3527 non-null   int32
#  7   avg_glucose_level  3527 non-null   float64
#  8   bmi                3527 non-null   float64
#  9   smoking_status     3527 non-null   int32
#  10  stroke             3527 non-null   int64
# dtypes: float64(3), int32(4), int64(4)
# memory usage: 404.6 KB

# %%
lr_X = df[['hypertension']] # independent variable
lr_y = df['stroke'] # outcome variable

# Split data into training and testing sets
lr_X_train, lr_X_test, lr_y_train, lr_y_test = train_test_split(lr_X, lr_y, test_size=0.2, random_state=2)

# Fit logistic regression model
model = LogisticRegression()
model.fit(lr_X_train, lr_y_train)

# Predict stroke for test data
lr_y_pred = model.predict(lr_X_test)

lr_accuracy = accuracy_score(lr_y_test, lr_y_pred)
print("Accuracy:", lr_accuracy)
# Out:
# Accuracy: 0.9192634560906515

# %%
lr_conf_matrix = confusion_matrix(lr_y_test, lr_y_pred)
plt.figure(figsize=(5, 3))
sns.heatmap(lr_conf_matrix, annot=True, fmt="d", cmap="Blues", cbar=False)
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.title('Confusion Matrix')
plt.show()

# %%
lr_X = df_balanced_random_oversampling[['bmi']] # independent variable
lr_y = df_balanced_random_oversampling['stroke'] # outcome variable

# Split data into training and testing sets
lr_X_train, lr_X_test, lr_y_train, lr_y_test = train_test_split(lr_X, lr_y, test_size=0.2, random_state=2)

# Fit logistic regression model
model = LogisticRegression()
model.fit(lr_X_train, lr_y_train)

# Predict stroke for test data
lr_y_pred = model.predict(lr_X_test)

lr_accuracy = accuracy_score(lr_y_test, lr_y_pred)
print("Accuracy:", lr_accuracy)
# Out:
# Accuracy: 0.5121951219512195

# %%
lr_conf_matrix = confusion_matrix(lr_y_test, lr_y_pred)
plt.figure(figsize=(5, 3))
sns.heatmap(lr_conf_matrix, annot=True, fmt="d", cmap="Blues", cbar=False)
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.title('Confusion Matrix')
plt.show()

# %%
df_balanced_SMOTE.info()

# %%
lr_X = df_balanced_triple_stroke[['hypertension']] # independent variable
lr_y = df_balanced_triple_stroke['stroke'] # outcome variable

# Split data into training and testing sets
lr_X_train, lr_X_test, lr_y_train, lr_y_test = train_test_split(lr_X, lr_y, test_size=0.2, random_state=25)

# Fit logistic regression model
model = LogisticRegression()
model.fit(lr_X_train, lr_y_train)

# Predict stroke for test data
lr_y_pred = model.predict(lr_X_test)

lr_accuracy = accuracy_score(lr_y_test, lr_y_pred)
print("Accuracy:", lr_accuracy)

# %%
lr_conf_matrix = confusion_matrix(lr_y_test, lr_y_pred)
plt.figure(figsize=(5, 3))
sns.heatmap(lr_conf_matrix, annot=True, fmt="d", cmap="Blues", cbar=False)
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.title('Confusion Matrix')
plt.show()

# %% [markdown]
# ##### Evaluation

# %% [markdown]
# Accuracy

# %%
lr_accuracy = accuracy_score(lr_y_test, lr_y_pred)
print("Accuracy:", lr_accuracy)

# %% [markdown]
# An accuracy of approximately 93.81% suggests that the logistic regression model performs relatively well on the test data. However, accuracy alone may not provide a complete picture.

# %% [markdown]
# Confusion matrix

# %%
lr_conf_matrix = confusion_matrix(lr_y_test, lr_y_pred)
plt.figure(figsize=(5, 3))
sns.heatmap(lr_conf_matrix, annot=True, fmt="d", cmap="Blues", cbar=False)
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.title('Confusion Matrix')
plt.show()

# %% [markdown]
# **Confusion matrix indicates:**
# True Negatives (TN): 925
# False Negatives (FN): 0
# True Positives (TP): 0
# False Positives (FP): 61

# %% [markdown]
# A confusion matrix with no true positives (TP) suggests that the model predicted all instances as the negative class (no stroke) and did not predict any instances as the positive class (stroke). This could indicate a **problem with class imbalance**.

# %% [markdown]
# #### Other Algorithm

# %% [markdown]
# ##### Algorithm

# %% [markdown]
# ##### Evaluation

# %% [markdown]
# ## Notes

# %%
#séparer correlation variable continu/discontinu et pearson ou dautre metrics

# %%
#fumeur unknown : cb sont stroke ? si 0 ou très peu : delete !?

# %%
#enelver enfant sous 8ans
